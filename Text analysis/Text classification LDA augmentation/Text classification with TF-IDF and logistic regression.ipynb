# %% [markdown]
# Import the libraries needed to manipulate data

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import pyodbc
plt.style.use('ggplot')
# %matplotlib inline

# %% [markdown]
# connect to the DailyMLResults database and get the data needed for this run

# %%
import pyodbc
conn = pyodbc.connect(r'Driver={SQL Server};Server=uatdotdatarpt;Database=DailyMLResults;Trusted_Connection=yes;OPTION=3;applicationintent=readonly;')
data = pd.read_sql("""SELECT Title, SourceLink, Modified_IsSecurity FROM MSSecurity_3 WITH (NOLOCK)
        WHERE Type IN ('bug', 'Compliance Issue', 'Defect', 'Issue', 'RDBug')
        AND AreaPath NOT LIKE '%RD\OneComplianceTest%' 
        AND AreaPath NOT LIKE '%\ClientManagement%'
        AND (IsDataDraft = 0 OR IsDataDraft IS NULL) 

UNION
SELECT Title, SourceLink, Modified_IsSecurity FROM Not_MSSecurity_3 WITH (NOLOCK)
        WHERE Type IN ('bug', 'Compliance Issue', 'Defect', 'Issue', 'RDBug')
        AND AreaPath NOT LIKE '%RD\OneComplianceTest%' 
        AND AreaPath NOT LIKE '%\ClientManagement%'
        AND (IsDataDraft = 0 OR IsDataDraft IS NULL) 

UNION
SELECT Title, SourceLink, Modified_IsSecurity FROM Not_Labeled_3 WITH (NOLOCK)
        WHERE Type IN ('bug', 'Compliance Issue', 'Defect', 'Issue', 'RDBug')
        AND AreaPath NOT LIKE '%RD\OneComplianceTest%' 
        AND AreaPath NOT LIKE '%\ClientManagement%'
        AND (IsDataDraft = 0 OR IsDataDraft IS NULL ) """, conn)
conn.close()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8863375 entries, 0 to 8863374
# Data columns (total 3 columns):
# Title                  object
# SourceLink             object
# Modified_IsSecurity    bool
# dtypes: bool(1), object(2)
# memory usage: 143.7+ MB

# %% [markdown]
# Define functions to clean the data

# %%
#Rmoves aldd urls from a title
import re
def clean_review_html(raw_data):
    text = re.sub(r'(https|http)?:\/\/(\w|\.|\/|\$|\?|\=|\&|\%)*\b',' ', raw_data, flags=re.MULTILINE)
    letters_only=re.sub('\s+',' ', text)
    return letters_only

#removes all paths from the titles
def clean_review_path(raw_data):
    raw_text = re.sub(r'(\w+):(\\[A-Z0-9a-z_-]*\s*[A-Za-z0-9_-]*)?(\\[A-Za-z0-9_-]*\s*[A-Za-z0-9_-]*)*\b', '', raw_data, flags=re.MULTILINE)
    removed_path = re.sub(r'(\w+):(\[A-Z0-9a-z_-]*\s*[A-Za-z0-9_-]*)?(\[A-Za-z0-9_-]*\s*[A-Za-z0-9_-]*)*\b', '', raw_text, flags=re.MULTILINE)
    return removed_path

#Remove all punctuation marks from a string including underscores.
def remove_punctuation(text):
    return re.sub(r"[\\]", ' ',(' '.join(re.sub(r"[!\"#$%&'()*+,-./:;<=>?@[\]^_`{|}~]", ' ',text).split())))

#remove all words attached to '/' or '\'. this will remove all links that have not been removed
def remove_paths_urls(text):#'!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'
    return ' '.join([word for word in text.split() if '\\' not in word and '/' not in word])

# %%
# Split Title at upper case takes IAmTHEBoy you know => I Am THE Boy you know.
def split_on_uppercase(s, keep_contiguous=True):
    """  Args:
        s (str): string
        keep_contiguous (bool): flag to indicate we want to 
                                keep contiguous uppercase chars together
    """

    string_length = len(s)
    is_lower_around = (lambda: s[i-1].islower() or string_length > (i + 1) and s[i + 1].islower())
    start = 0
    parts = []
    for i in range(1, string_length):
        if s[i].isupper() and (not keep_contiguous or is_lower_around()):
            parts.append(s[start: i])
            start = i
    parts.append(s[start:])

    return " ".join(parts)
print(split_on_uppercase('TheLongANDANdeWindingRoad', True))
# Out:
# The Long ANDA Nde Winding Road

# %%
#remove all integers from titles.
def remove_integers(s):
    return re.sub(' \d+ ', ' ', s)
print(remove_punctuation('MSAzureIntune-Svc-IWPortal_Release_1608_CTIP'))
remove_integers(remove_punctuation('MSAzureIntune-Svc-IWPortal_Release_1608_CTIP'))
# Out:
# MSAzureIntune Svc IWPortal Release 1608 CTIP
# 'MSAzureIntune Svc IWPortal Release CTIP'

# %% [markdown]
# Following our discussions with Alok, we had decided to make all instances of PoliCheck to 'policheck'. here, I create a function to do so.

# %%
def deal_with_policheck(title):
    return re.sub('(PoliCheck)|(POLICHECK)|(poliCheck)', ' policheck ', title)
deal_with_policheck('''[ DotNet-CoreFx-Trusted_master ][ PoliCheck ] - Defect :''')
# Out:
# '[ DotNet-CoreFx-Trusted_master ][  policheck  ] - Defect :'

# %%
data['Title'] = data['Title'].apply(str)

# %%
data['Title'] = data['Title'].apply(deal_with_policheck)

# %%
data['No Urls'] = data['Title'].apply(clean_review_html)

# %%
data['No Paths'] = data['No Urls'].apply(clean_review_path)

# %%
data['No Links and Paths'] = data['No Paths'].apply(remove_paths_urls)
#This function is just to ensure that if some paths and urls were not removedby the 
#regular expression, they must be removed now

# %%
data['Split Upper'] = data['No Links and Paths'].apply(split_on_uppercase)

# %%
data['No Punctuation'] = data['Split Upper'].apply(remove_punctuation)

# %%
data['Clean Title'] = data['No Punctuation'].apply(remove_integers)

# %% [markdown]
# # Model Building¶
#
# We are going to build a bunch of models starting with unigrams and ending with trigrams (3=grams)
#
# We fist import the neccessary libraries, build a tfidf and a model.
#
# We end by validating the model on the validation set and getting output on the test set

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.externals import joblib

# %%
X_12, y_12 = data['Clean Title'], data['Modified_IsSecurity']
tv_12 = TfidfVectorizer(min_df = 0.00009, max_df = 0.5, use_idf = True, stop_words = 'english', ngram_range = (1,2))
X_12 = tv_12.fit_transform(X_12)
X_train_12, X_12_0, y_train_12, y_12_0 = train_test_split(X_12, y_12, test_size = 0.2, random_state = 42)
X_test_12, X_val_12, y_test_12, y_val_12 = train_test_split(X_12_0, y_12_0, test_size = 0.5, random_state = 42)
vocab_12 = tv_12.get_feature_names()
print(len(vocab_12))
# Out:
# 15179

# %% [markdown]
# Train a logistic regression model and Get predictions on the training, validation and whole dataset.

# %%
model_lr_12 = LogisticRegression(n_jobs = -1)
model_lr_12.fit(X_train_12, y_train_12)
# Out:
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
print('*'*15 + ' Results on Test set ' +'*'*15)
pred_12 = model_lr_12.predict(X_test_12)

score = metrics.accuracy_score(y_test_12, pred_12)
print("accuracy:   %0.3f" % score)

f1_score = metrics.f1_score(y_test_12, pred_12)
print("f1_score:   %0.3f" % f1_score)

precision_score = metrics.precision_score(y_test_12, pred_12)
print("precision_score:   %0.3f" % precision_score)

recall_score = metrics.recall_score(y_test_12, pred_12)
print("recall_score:   %0.3f" % recall_score)

roc_auc_score = metrics.roc_auc_score(y_test_12, pred_12)
print("roc_auc_score:   %0.3f" % roc_auc_score)
fpr, tpr, thresh = metrics.roc_curve(y_test_12, pred_12)

print("classification report:")
print(metrics.classification_report(y_test_12, pred_12))

print("confusion matrix:")
print(metrics.confusion_matrix(y_test_12, pred_12))

print('*'*15 + ' Results on Validation set ' +'*'*15, '\n')
pred_0_12 = model_lr_12.predict(X_val_12)

score = metrics.accuracy_score(y_val_12, pred_0_12)
print("accuracy:   %0.3f" % score)

f1_score = metrics.f1_score(y_val_12, pred_0_12)
print("f1_score:   %0.3f" % f1_score)

precision_score = metrics.precision_score(y_val_12, pred_0_12)
print("precision_score:   %0.3f" % precision_score)

recall_score = metrics.recall_score(y_val_12, pred_0_12)
print("recall_score:   %0.3f" % recall_score)

roc_auc_score = metrics.roc_auc_score(y_val_12, pred_0_12)
print("roc_auc_score:   %0.3f" % roc_auc_score)
fpr, tpr, thresh = metrics.roc_curve(y_val_12, pred_0_12)

print("classification report:")
print(metrics.classification_report(y_val_12, pred_0_12))

print("confusion matrix:")
print(metrics.confusion_matrix(y_val_12, pred_0_12))
print('*'*25 + ' END! ' +'*'*25)
# Out:
# *************** Results on Test set ***************
# accuracy:   0.998
# f1_score:   0.987
# precision_score:   0.993
# recall_score:   0.982
# roc_auc_score:   0.991
# classification report:
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00    804887
#        True       0.99      0.98      0.99     81450
#
# avg / total       1.00      1.00      1.00    886337
#
# confusion matrix:
# [[804313    574]
#  [  1487  79963]]
# *************** Results on Validation set ***************
#
# accuracy:   0.998
# f1_score:   0.988
# precision_score:   0.993
# recall_score:   0.982
# roc_auc_score:   0.991
# classification report:
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00    804596
#        True       0.99      0.98      0.99     81742
#
# avg / total       1.00      1.00      1.00    886338
#
# confusion matrix:
# [[804068    528]
#  [  1447  80295]]
# ************************* END! *************************

# %%
print('*'*15 + ' Results on the entire set ' +'*'*15, '\n')
pred__12 = model_lr_12.predict(X_12)

score = metrics.accuracy_score(y_12, pred__12)
print("accuracy:   %0.3f" % score)

f1_score = metrics.f1_score(y_12, pred__12)
print("f1_score:   %0.3f" % f1_score)

precision_score = metrics.precision_score(y_12, pred__12)
print("precision_score:   %0.3f" % precision_score)

recall_score = metrics.recall_score(y_12, pred__12)
print("recall_score:   %0.3f" % recall_score)

roc_auc_score = metrics.roc_auc_score(y_12, pred__12)
print("roc_auc_score:   %0.3f" % roc_auc_score)
fpr, tpr, thresh = metrics.roc_curve(y_12, pred__12)

print("classification report:")
print(metrics.classification_report(y_12, pred__12))

print("confusion matrix:")
print(metrics.confusion_matrix(y_12, pred__12))
print('*'*25 + ' END! ' +'*'*25)
# Out:
# *************** Results on the entire set ***************
#
# accuracy:   0.998
# f1_score:   0.988
# precision_score:   0.993
# recall_score:   0.983
# roc_auc_score:   0.991
# classification report:
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00   8048081
#        True       0.99      0.98      0.99    815294
#
# avg / total       1.00      1.00      1.00   8863375
#
# confusion matrix:
# [[8042709    5372]
#  [  13982  801312]]
# ************************* END! *************************

# %% [markdown]
# Cross validate the model on the validation set using
#
# 1) accuracy,  <br>
#   2) f1_macro,  <br>
#   3) recall, and <br>
#   4) precision <br>asscoring methods

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(model_lr_12, X_val_12, y_val_12, scoring = 'f1_macro', cv = 10)
print(scores)
print('Mean f1 score of the 10 scores: %s'%(round(100*scores.mean(), 2)))
# Out:
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# [ 0.9873935   0.9885395   0.98861575  0.9868803   0.98824956  0.98830399
#   0.98849316  0.98781979  0.98818651  0.98856528]
# Mean f1 score of the 10 scores: 98.81

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(model_lr_12, X_val_12, y_val_12, scoring = 'accuracy', cv = 10)
print(scores)
print('Mean accuracy score of the 10 scores: %s'%(round(100*scores.mean(), 2)))
# Out:
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# [ 0.99583686  0.99620917  0.99624298  0.99566758  0.99611887  0.99613015
#   0.9961978   0.99597215  0.99609626  0.99622037]
# Mean accuracy score of the 10 scores: 99.61

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(model_lr_12, X_val_12, y_val_12, scoring = 'recall', cv = 10)
print(scores)
print('Mean recall score of the 10 scores: %s'%(round(100*scores.mean(), 2)))
# Out:
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# [ 0.96195719  0.96574924  0.96354294  0.96109616  0.96378762  0.96574505
#   0.96464399  0.96427698  0.96415464  0.96513335]
# Mean recall score of the 10 scores: 96.4

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(model_lr_12, X_val_12, y_val_12, scoring = 'precision', cv = 10)
print(scores)
print('Mean precision score of the 10 scores: %s'%(round(100*scores.mean(), 2)))
# Out:
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# [ 0.99267862  0.99295686  0.99557578  0.99166877  0.99394398  0.99208244
#   0.99394933  0.99182081  0.99331989  0.99370198]
# Mean precision score of the 10 scores: 99.32

# %% [markdown]
# Add columns for the predictions and the probability of prediction for each title.

# %%
data['Predictions'], data['Pred_Prob0'], data['Pred_Prob1']= model_lr_12.predict(X_12), model_lr_12.predict_proba(X_12)[:,0], model_lr_12.predict_proba(X_12)[:,1]

# %% [markdown]
# Save the false Positives and false negatives to a csv file for further analysis.

# %%
data[(data['Modified_IsSecurity'] == True) & (data['Predictions'] == False)][['Title','SourceLink','Modified_IsSecurity','Predictions','Pred_Prob0','Pred_Prob1']].to_csv('False Negatives bug,isue,compileETC06-07-18.csv', index = False)
data[(data['Modified_IsSecurity'] == False) & (data['Predictions'] == True)][['Title','SourceLink','Modified_IsSecurity','Predictions','Pred_Prob0','Pred_Prob1']].to_csv('False Positives bug,isue,compileETC06-07-18.csv', index = False)

# %% [markdown]
# Save the tfidf and the the model for future references

# %%
from sklearn.externals import joblib
joblib.dump(model_lr_12, 'model_lr_12_bugs_rdbugs_isuesETC.pkl')
joblib.dump(tv_12, 'tv_12_bugs_rdbugs_isuesETC.pkl')
# Out:
# ['tv_12_bugs_rdbugs_isuesETC.pkl']

# %% [markdown]
# # Working with the whole dataset <br>(by removing the where condition in the query)
# <br>We will also add "Type" to the rows being selected here because we want to see how well a new model will generalize.

# %%
import pyodbc
conn = pyodbc.connect(r'Driver={SQL Server};Server=uatdotdatarpt;Database=DailyMLResults;Trusted_Connection=yes;OPTION=3;applicationintent=readonly;')
data = pd.read_sql("""SELECT Title, SourceLink, Modified_IsSecurity, Type FROM MSSecurity_3 WITH (NOLOCK)
        WHERE AreaPath NOT LIKE '%RD\OneComplianceTest%' 
        AND AreaPath NOT LIKE '%\ClientManagement%'
        AND (IsDataDraft = 0 OR IsDataDraft IS NULL) 

UNION
SELECT Title, SourceLink, Modified_IsSecurity, Type FROM Not_MSSecurity_3 WITH (NOLOCK)
        WHERE AreaPath NOT LIKE '%RD\OneComplianceTest%' 
        AND AreaPath NOT LIKE '%\ClientManagement%'
        AND (IsDataDraft = 0 OR IsDataDraft IS NULL) 

UNION
SELECT Title, SourceLink, Modified_IsSecurity, Type FROM Not_Labeled_3 WITH (NOLOCK)
        WHERE AreaPath NOT LIKE '%RD\OneComplianceTest%' 
        AND AreaPath NOT LIKE '%\ClientManagement%'
        AND (IsDataDraft = 0 OR IsDataDraft IS NULL ) """, conn)
conn.close()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15890011 entries, 0 to 15890010
# Data columns (total 4 columns):
# Title                  object
# SourceLink             object
# Modified_IsSecurity    bool
# Type                   object
# dtypes: bool(1), object(3)
# memory usage: 378.8+ MB

# %%
data['Title'] = data['Title'].apply(str)

# %%
data['Title'] = data['Title'].apply(deal_with_policheck)

# %%
data['No Urls'] = data['Title'].apply(clean_review_html)

# %%
data['No Paths'] = data['No Urls'].apply(clean_review_path)

# %%
data['No Links and Paths'] = data['No Paths'].apply(remove_paths_urls)

# %%
data['Split Upper'] = data['No Links and Paths'].apply(split_on_uppercase)

# %%
data['No Punctuation'] = data['Split Upper'].apply(remove_punctuation)

# %%
data['Clean Title'] = data['No Punctuation'].apply(remove_integers)

# %% [markdown]
# Get a tfidf and fit a logistic regression model.

# %%
X_12, y_12 = data['Clean Title'], data['Modified_IsSecurity']
tv_12 = TfidfVectorizer(min_df = 0.00009, max_df = 0.5, use_idf = True, stop_words = 'english', ngram_range = (1,2))
X_12 = tv_12.fit_transform(X_12)
X_train_12, X_12_0, y_train_12, y_12_0 = train_test_split(X_12, y_12, test_size = 0.2, random_state = 42)
X_test_12, X_val_12, y_test_12, y_val_12 = train_test_split(X_12_0, y_12_0, test_size = 0.5, random_state = 42)
vocab_12 = tv_12.get_feature_names()
print(len(vocab_12))
# Out:
# 13835

# %%
model_lr_12 = LogisticRegression(n_jobs = -1)
model_lr_12.fit(X_train_12, y_train_12)
# Out:
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=-1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %% [markdown]
# Get predictions on the training and validation sets

# %%
print('*'*15 + ' Results on Test set ' +'*'*15)
pred_12 = model_lr_12.predict(X_test_12)

score = metrics.accuracy_score(y_test_12, pred_12)
print("accuracy:   %0.3f" % score)

f1_score = metrics.f1_score(y_test_12, pred_12)
print("f1_score:   %0.3f" % f1_score)

precision_score = metrics.precision_score(y_test_12, pred_12)
print("precision_score:   %0.3f" % precision_score)

recall_score = metrics.recall_score(y_test_12, pred_12)
print("recall_score:   %0.3f" % recall_score)

roc_auc_score = metrics.roc_auc_score(y_test_12, pred_12)
print("roc_auc_score:   %0.3f" % roc_auc_score)
fpr, tpr, thresh = metrics.roc_curve(y_test_12, pred_12)

print("classification report:")
print(metrics.classification_report(y_test_12, pred_12))

print("confusion matrix:")
print(metrics.confusion_matrix(y_test_12, pred_12))

print('*'*15 + ' Results on Validation set ' +'*'*15, '\n')
pred_0_12 = model_lr_12.predict(X_val_12)

score = metrics.accuracy_score(y_val_12, pred_0_12)
print("accuracy:   %0.3f" % score)

f1_score = metrics.f1_score(y_val_12, pred_0_12)
print("f1_score:   %0.3f" % f1_score)

precision_score = metrics.precision_score(y_val_12, pred_0_12)
print("precision_score:   %0.3f" % precision_score)

recall_score = metrics.recall_score(y_val_12, pred_0_12)
print("recall_score:   %0.3f" % recall_score)

roc_auc_score = metrics.roc_auc_score(y_val_12, pred_0_12)
print("roc_auc_score:   %0.3f" % roc_auc_score)
fpr, tpr, thresh = metrics.roc_curve(y_val_12, pred_0_12)

print("classification report:")
print(metrics.classification_report(y_val_12, pred_0_12))

print("confusion matrix:")
print(metrics.confusion_matrix(y_val_12, pred_0_12))
print('*'*25 + ' END! ' +'*'*25)
# Out:
# *************** Results on Test set ***************
# accuracy:   0.995
# f1_score:   0.968
# precision_score:   0.988
# recall_score:   0.949
# roc_auc_score:   0.974
# classification report:
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00   1464204
#        True       0.99      0.95      0.97    124797
#
# avg / total       1.00      1.00      1.00   1589001
#
# confusion matrix:
# [[1462749    1455]
#  [   6394  118403]]
# *************** Results on Validation set ***************
#
# accuracy:   0.995
# f1_score:   0.968
# precision_score:   0.988
# recall_score:   0.949
# roc_auc_score:   0.974
# classification report:
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00   1464600
#        True       0.99      0.95      0.97    124402
#
# avg / total       1.00      1.00      1.00   1589002
#
# confusion matrix:
# [[1463190    1410]
#  [   6399  118003]]
# ************************* END! *************************

# %% [markdown]
# Get predictions on the entire dataset

# %%
print('*'*15 + ' Results on the entire set ' +'*'*15, '\n')
pred__12 = model_lr_12.predict(X_12)

score = metrics.accuracy_score(y_12, pred__12)
print("accuracy:   %0.3f" % score)

f1_score = metrics.f1_score(y_12, pred__12)
print("f1_score:   %0.3f" % f1_score)

precision_score = metrics.precision_score(y_12, pred__12)
print("precision_score:   %0.3f" % precision_score)

recall_score = metrics.recall_score(y_12, pred__12)
print("recall_score:   %0.3f" % recall_score)

roc_auc_score = metrics.roc_auc_score(y_12, pred__12)
print("roc_auc_score:   %0.3f" % roc_auc_score)
fpr, tpr, thresh = metrics.roc_curve(y_12, pred__12)

print("classification report:")
print(metrics.classification_report(y_12, pred__12))

print("confusion matrix:")
print(metrics.confusion_matrix(y_12, pred__12))
print('*'*25 + ' END! ' +'*'*25)
# Out:
# *************** Results on the entire set ***************
#
# accuracy:   0.995
# f1_score:   0.968
# precision_score:   0.988
# recall_score:   0.950
# roc_auc_score:   0.974
# classification report:
#              precision    recall  f1-score   support
#
#       False       1.00      1.00      1.00  14641962
#        True       0.99      0.95      0.97   1248049
#
# avg / total       1.00      1.00      1.00  15890011
#
# confusion matrix:
# [[14627800    14162]
#  [   62991  1185058]]
# ************************* END! *************************

# %%
62991/1245058
# Out:
# 0.050592823788128745

# %% [markdown]
# Perform a 10-fold cross-balidation and print the results.

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(model_lr_12, X_val_12, y_val_12, scoring = 'recall', cv = 10)
print(scores)
print('Mean recall score of the 10 scores: %s'%(round(100*scores.mean(), 2)))
# Out:
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# [ 0.93336549  0.93457118  0.9335209   0.93247588  0.93802251  0.93625402
#   0.93649518  0.93842444  0.93536977  0.93456592]
# Mean recall score of the 10 scores: 93.53

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(model_lr_12, X_val_12, y_val_12, scoring = 'accuracy', cv = 10)
print(scores)
print('Mean accuracy score of the 10 scores: %s'%(round(100*scores.mean(), 2)))
# Out:
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# [ 0.99399626  0.9939648   0.99394588  0.99381372  0.99431718  0.99405286
#   0.99415356  0.99438011  0.99409692  0.99408433]
# Mean accuracy score of the 10 scores: 99.41

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(model_lr_12, X_val_12, y_val_12, scoring = 'precision', cv = 10)
print(scores)
print('Mean precision score of the 10 scores: %s'%(round(100*scores.mean(), 2)))
# Out:
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# [ 0.98934992  0.98768264  0.98850868  0.98782253  0.98881451  0.98711755
#   0.98820935  0.9892382   0.98861512  0.98927842]
# Mean precision score of the 10 scores: 98.85

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(model_lr_12, X_val_12, y_val_12, scoring = 'f1_macro', cv = 10)
print(scores)
print('Mean f1_macro score of the 10 scores: %s'%(round(100*scores.mean(), 2)))
# Out:
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# C:\Anaconda\lib\site-packages\sklearn\linear_model\logistic.py:1228: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = -1.
#   " = {}.".format(self.n_jobs))
# [ 0.97864679  0.97856335  0.97847589  0.97800186  0.97983651  0.97889708
#   0.97924652  0.9800598   0.97903037  0.97897132]
# Mean f1_macro score of the 10 scores: 97.9

# %%
data.columns
# Out:
# Index(['Title', 'SourceLink', 'Modified_IsSecurity', 'Type', 'No Urls',
#        'No Paths', 'No Links and Paths', 'Split Upper', 'No Punctuation',
#        'Clean Title'],
#       dtype='object')

# %% [markdown]
# Get the predictions for each title and the probability attributed to that prediction.

# %%
data['Predictions'], data['Pred_Proba0'], data['Pred_Proba1']=model_lr_12.predict(X_12), model_lr_12.predict_proba(X_12)[:,0], model_lr_12.predict_proba(X_12)[:,1]

# %%
fn,fp = data[(data['Modified_IsSecurity'] == True) & (data['Predictions'] == False)][['Title', 'SourceLink','Modified_IsSecurity','Predictions','Pred_Proba0','Pred_Proba1','Type']], data[(data['Modified_IsSecurity'] == False) & (data['Predictions'] == True)][['Title', 'SourceLink','Modified_IsSecurity','Predictions','Pred_Proba0','Pred_Proba1','Type']]

# %% [markdown]
# Group all the Titles, false negatives and false positives by type

# %%
grouped_type = pd.DataFrame(data.groupby(by = ['Type']).count()['Title'])
grouped_type_fp = pd.DataFrame(fp.groupby(by = ['Type']).count()['Title'])
grouped_type_fn = pd.DataFrame(fn.groupby(by = ['Type']).count()['Title'])

# %%
grouped_type.columns
# Out:
# Index(['Title'], dtype='object')

# %%
grouped_type_fn.head()
# Out:
#                   Title
# Type
# Assessment           11
# Bug               13307
# Criterion            23
# Customer Promise     41
# Defect             2941

# %%
grouped_type.index
# Out:
# Index(['Accessibility Exemption', 'Accessibility Plan', 'Assessment', 'BUG',
#        'Blanket Exception', 'Bug', 'Compliance Review', 'Criterion',
#        'Customer Ask', 'Customer Promise', 'DTS Task', 'Defect', 'Deliverable',
#        'Dependency', 'Design Requirement', 'Design Task', 'Epic', 'Exception',
#        'Experience', 'External Dependency', 'Feature', 'Feature Release',
#        'FeedbackTicket', 'Icon Request', 'Impediment', 'Improvement', 'Issue',
#        'Live Site Incident', 'Partner Ask', 'Product Backlog Item', 'RDBug',
#        'RDTask', 'ReadMe Input', 'Release Exception', 'Release Record',
#        'Release Security and Fundamentals Checklist', 'Requirement', 'Roadmap',
#        'Scenario', 'Security Checklist', 'Service Catalog', 'Service Change',
#        'Slice', 'Story', 'TASK', 'Task', 'Task Group', 'UI Component',
#        'User Story', 'VSEng Service Incident', 'Work Item'],
#       dtype='object', name='Type')

# %% [markdown]
# Concatenate all three dataframes

# %%
concat_grouped_by = pd.concat([grouped_type, grouped_type_fn, grouped_type_fp], axis = 1)
concat_grouped_by.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51 entries, Accessibility Exemption to Work Item
# Data columns (total 3 columns):
# Title    51 non-null int64
# Title    33 non-null float64
# Title    27 non-null float64
# dtypes: float64(2), int64(1)
# memory usage: 1.6+ KB

# %%
concat_grouped_by.columns=['Title', 'fn_title', 'fp_title']
concat_grouped_by.head()
# Out:
#                          Title  fn_title  fp_title
# Accessibility Exemption     15       NaN       NaN
# Accessibility Plan         116       NaN       2.0
# Assessment                8223      11.0      21.0
# BUG                        274       NaN       NaN
# Blanket Exception           28       NaN       NaN

# %%
concat_grouped_by['Total_Type'] = concat_grouped_by.sum()
concat_grouped_by.head()
# Out:
#                          Title  fn_title  fp_title  Total_Type
# Accessibility Exemption     15       NaN       NaN         NaN
# Accessibility Plan         116       NaN       2.0         NaN
# Assessment                8223      11.0      21.0         NaN
# BUG                        274       NaN       NaN         NaN
# Blanket Exception           28       NaN       NaN         NaN

# %% [markdown]
# Create a column for the percentage of false negatives and false positives for each work Item type

# %%
concat_grouped_by['Percent_fn'] = round(100*concat_grouped_by['fn_title']/concat_grouped_by['Title'],3)
concat_grouped_by['Percent_fp'] = round(100*concat_grouped_by['fp_title']/concat_grouped_by['Title'],3)
concat_grouped_by.head()
# Out:
#                          Title  fn_title  fp_title  Total_Type  Percent_fn  \
# Accessibility Exemption     15       NaN       NaN         NaN         NaN
# Accessibility Plan         116       NaN       2.0         NaN         NaN
# Assessment                8223      11.0      21.0         NaN       0.134
# BUG                        274       NaN       NaN         NaN         NaN
# Blanket Exception           28       NaN       NaN         NaN         NaN
#
#                          Percent_fp
# Accessibility Exemption         NaN
# Accessibility Plan            1.724
# Assessment                    0.255
# BUG                             NaN
# Blanket Exception               NaN

# %% [markdown]
# Rename the columns to more intuitive names and checkout the head of the resulting dataframe.

# %%
concat_grouped_by.rename(inplace = True, columns={'Title':'numTitles', 'fn_title':'numFN', 'fp_title':'numFP', 'Total_Type':'Total_Type', 'Percent_fn':'Percent_fn','Percent_fp':'Percent_fp'})

# %%
concat_grouped_by.drop('Total_Type', inplace = True, axis = 1)

# %%
concat_grouped_by.head()
# Out:
#                          numTitles  numFN  numFP  Percent_fn  Percent_fp
# Accessibility Exemption         15    NaN    NaN         NaN         NaN
# Accessibility Plan             116    NaN    2.0         NaN       1.724
# Assessment                    8223   11.0   21.0       0.134       0.255
# BUG                            274    NaN    NaN         NaN         NaN
# Blanket Exception               28    NaN    NaN         NaN         NaN

# %% [markdown]
# Save the grouped data to csv files for further analylis

# %%
concat_grouped_by.to_csv('False Negatives and false Positives grouped by workItem Type.csv')

# %% [markdown]
# Save the false negatives and false positives of this model to a csv file for further anlysis.

# %%
fn.to_csv('False Negatives all work item type 06-08-2018.csv', index = False)
fp.to_csv('False Positives all work item type 06-08-2018.csv', index = False)

# %%
fp.head()
# Out:
#                                                   Title  \
# 2403   (IQP) A certain SecureIslands API call not wo...
# 4797   [PPE] 404's for GetServerSyncUpdateDecryption...
# 6963  ------------------- Infrastructure Cutline = O...
# 7462                                   🛂 Configure RBAC
# 8882   Develop standard access control testing crite...
#
#                                              SourceLink  Modified_IsSecurity  \
# 2403  https://msazure.visualstudio.com/DefaultCollec...                False
# 4797  https://microsoft.visualstudio.com/DefaultColl...                False
# 6963  https://o365exchange.visualstudio.com/DefaultC...                False
# 7462  https://msengagement.visualstudio.com/DefaultC...                False
# 8882  https://microsoftit.visualstudio.com/DefaultCo...                False
#
#       Predictions  Pred_Proba0  Pred_Proba1        Type
# 2403         True     0.099604     0.900396         Bug
# 4797         True     0.039426     0.960574         Bug
# 6963         True     0.039439     0.960561  User Story
# 7462         True     0.276454     0.723546     Feature
# 8882         True     0.364225     0.635775        Task

# %% [markdown]
# Save the logistic regression model and its tfidf

# %%
joblib.dump(model_lr_12, 'model_lr_12_allWorkItemTypes.pkl')
joblib.dump(tv_12, 'tv_12_allWorkItemTypes.pkl')
# Out:
# ['tv_12_allWorkItemTypes.pkl']

# %% [markdown]
# # Working on the "msasg" data
# Get predictions for the msasg data

# %% [markdown]
# Get the data

# %%
conn = pyodbc.connect(r'Driver={SQL Server};Server=dotdatarpt;Database=TwCDataWarehouse;Trusted_Connection=yes;OPTION=3;applicationintent=readonly;')

msasg_data = pd.read_sql('''SELECT DISTINCT Title, SourceLink, RequirementCollectionDID 
                          FROM workitemextensions WITH (NOLOCK)
                          WHERE IsActive=1 and LatestFlag=1 
                          AND SourceLink like '%msasg.visualstudio.com%' ''', conn)
conn.close()
# and Type LIKE '%bug%'

# %%
msasg_data.head()
# Out:
#   Title                                         SourceLink  \
# 0  None  https://msasg.visualstudio.com/DefaultCollecti...
# 1  None  https://msasg.visualstudio.com/DefaultCollecti...
# 2  None  https://msasg.visualstudio.com/DefaultCollecti...
# 3  None  https://msasg.visualstudio.com/DefaultCollecti...
# 4  None  https://msasg.visualstudio.com/DefaultCollecti...
#
#   RequirementCollectionDID
# 0                     None
# 1                     None
# 2                     None
# 3                     None
# 4                     None

# %%
msasg_data.tail()
# Out:
#                               Title  \
# 1071257              首页和verp页脚加QQ群号
# 1071258                   駄菓子クーポン設置
# 1071259              高德离线地图实现方式调研报告
# 1071260                   高校简介 data
# 1071261  \tLabel Guideline update
#
#                                                 SourceLink  \
# 1071257  https://msasg.visualstudio.com/DefaultCollecti...
# 1071258  https://msasg.visualstudio.com/DefaultCollecti...
# 1071259  https://msasg.visualstudio.com/DefaultCollecti...
# 1071260  https://msasg.visualstudio.com/DefaultCollecti...
# 1071261  https://msasg.visualstudio.com/DefaultCollecti...
#
#         RequirementCollectionDID
# 1071257                     None
# 1071258                     None
# 1071259                     None
# 1071260                     None
# 1071261                     None

# %% [markdown]
# Preprocess the data

# %%
msasg_data['Title'] = msasg_data['Title'].apply(str)

# %%
msasg_data['Title'] = msasg_data['Title'].apply(deal_with_policheck)

# %%
msasg_data['No Urls'] = msasg_data['Title'].apply(clean_review_html)

# %%
msasg_data['No Paths'] = msasg_data['No Urls'].apply(clean_review_path)

# %%
msasg_data['No Links and Paths'] = msasg_data['No Paths'].apply(remove_paths_urls)

# %%
msasg_data['Split Upper'] = msasg_data['No Links and Paths'].apply(split_on_uppercase)

# %%
msasg_data['No Punctuation'] = msasg_data['Split Upper'].apply(remove_punctuation)

# %%
msasg_data['Clean Title'] = msasg_data['No Punctuation'].apply(remove_integers)

# %%
X = tv_12.transform(msasg_data['No Punctuation'])

# %%
msasg_data['Predictions'], msasg_data['Pred_Proba0'], msasg_data['Pred_Proba1'] = model_lr_12.predict(X), model_lr_12.predict_proba(X)[:,0], model_lr_12.predict_proba(X)[:,1]

# %%
msasg_data['Predictions'].value_counts()
# Out:
# False    1033208
# True       38054
# Name: Predictions, dtype: int64

# %%
msasg_data['Predictions_fewTypes'].value_counts()
# Out:
# False    1033709
# True       37553
# Name: Predictions_fewTypes, dtype: int64

# %%
print('Percentage predicted as security: %f'%(round(100* 38054/(38054+1033208), 5))+'%.')
# Out:
# Percentage predicted as security: 3.552260%.

# %% [markdown]
# Get predictions for the msasg titles using model built on <br>
# <br> `Type IN ('bug', 'Compliance Issue', 'Defect', 'Issue', 'RDBug')`

# %%
model = joblib.load('model_lr_12_bugs_rdbugs_isuesETC.pkl')
tv = joblib.load('tv_12_bugs_rdbugs_isuesETC.pkl')

# %%
X1 = tv.transform(msasg_data['No Punctuation'])

# %%
msasg_data['Predictions_fewTypes'], msasg_data['Pred_Proba0_fewTypes'], msasg_data['Pred_Proba1_fewTypes'] = model.predict(X1), model.predict_proba(X1)[:,0], model.predict_proba(X1)[:,1]

# %% [markdown]
# Get the predictions where the model built on all work items types do not agree with the model built on work <br>items with `Type IN ('bug', 'Compliance Issue', 'Defect', 'Issue', 'RDBug')`

# %%
msasg_data[msasg_data['Predictions'] != msasg_data['Predictions_fewTypes']]
# Out:
#                                                      Title  \
# 6575     (Via External Team) Verify Decryption is Worki...
# 6914     *RELEASE BLOCKER* - Secret not working between...
# 6917     *RELEASE BLOCKER* Add secret token communicati...
# 6936     *RELEASE BLOCKER* Setup secret between SNR/XAP...
# 15224    [ MSASG_AdsCX_retail ][ CodeAnalysis ] - Defec...
# 15225    [ MSASG_AdsCX_retail ][ CodeAnalysis ] - Defec...
# 15937    [ MSASG_Agilemining-Packages_retail ][ CodeAna...
# 15972    [ MSASG_AnB_retail ][ CodeAnalysis ] - Defect ...
# 21996    [ MSASG_Indexquality_Malware_Prod_retail ][ Co...
# 33656    [ Scheduling] Setting up Secure Service Fabric...
# 34299    [#004890] BingAds - Unsafe SSL TrustManager De...
# 34301    [#006062] Insecure Random Number Generator Usage
# 34303    [#006741] - Insecure Random Number Generator U...
# 34367    [@Work] Address issues identified by static co...
# 34370    [@Work] Classify and handle source code and da...
# 43049    [AE365] Merge code from Aether to AE365 - Secu...
# 43222                          [AetherSecure] Add Counters
# 43226                    [AetherSecure] Fix Cache Deletion
# 43228                       [AetherSecure] GC for Services
# 43229         [AetherSecure] Health Checker for ExeWorkers
# 43230             [AetherSecure] Implement GC for Services
# 43231    [AetherSecure] Investigate Cache Deletion Fail...
# 43232      [AetherSecure] Investigate HealthChecker Issues
# 43233               [AetherSecure] Investigate Memory Leak
# 43236          [AetherSecure] Machines Availability Issues
# 43237                 [AetherSecure] Random FolderName Fix
# 43239         [AetherSecure] Show Realtime STDOut/Err Link
# 43241      [AetherSecure] Test & Deploy New SocialAccessor
# 43764    [Agora Crash][]: MainPage: client_GetNavInfoCo...
# 45333    [Analysis] Use Login IP from CCUI for PI Fraud...
# ...                                                    ...
# 1038456  Verify that Shared Access Signatures (SAS) are...
# 1038457  Verify that Shared Access Signatures (SAS) are...
# 1038458  Verify that Shared Access Signatures (SAS) are...
# 1038459  Verify that Shared Access Signatures (SAS) are...
# 1038495  Verify the appropriate Microsoft Account Ident...
# 1038496  Verify the appropriate Microsoft Account Ident...
# 1038497  Verify the appropriate Microsoft Account Ident...
# 1038498  Verify the appropriate Microsoft Account Ident...
# 1038499  Verify the appropriate Microsoft Account Ident...
# 1038500  Verify the appropriate Microsoft Account Ident...
# 1038501  Verify the appropriate Microsoft Account Ident...
# 1038502  Verify the appropriate Microsoft Account Ident...
# 1038503  Verify the appropriate Microsoft Account Ident...
# 1038504  Verify the appropriate Microsoft Account Ident...
# 1038505  Verify the appropriate Microsoft Account Ident...
# 1038506  Verify the appropriate Microsoft Account Ident...
# 1038507  Verify the appropriate Microsoft Account Ident...
# 1038508  Verify the appropriate Microsoft Account Ident...
# 1039159  Very Nice App, I like app,  Just 5 min. of use...
# 1047263                 Virus scan blocking files on agent
# 1048850                       VS Plugins for Secure Coding
# 1048959               VSOHelper should decrypt config last
# 1052463    Weekly Recall Analysis for Phishing Escalations
# 1056583                                 WLSP Phishing data
# 1057158  Work with IRMC PMO team to discover their fram...
# 1058846  Working Set + Latency Stream: BondModelFactory...
# 1065219    Write the playbook for PrivSec Breach Scenarios
# 1066691  XAP: Enable secure traffic between Bing and Ya...
# 1068971                XSS on routes with query parameters
# 1069690  You almost gave me a heart attack. You showed ...
#
#                                                 SourceLink  \
# 6575     https://msasg.visualstudio.com/DefaultCollecti...
# 6914     https://msasg.visualstudio.com/DefaultCollecti...
# 6917     https://msasg.visualstudio.com/DefaultCollecti...
# 6936     https://msasg.visualstudio.com/DefaultCollecti...
# 15224    https://msasg.visualstudio.com/DefaultCollecti...
# 15225    https://msasg.visualstudio.com/DefaultCollecti...
# 15937    https://msasg.visualstudio.com/DefaultCollecti...
# 15972    https://msasg.visualstudio.com/DefaultCollecti...
# 21996    https://msasg.visualstudio.com/DefaultCollecti...
# 33656    https://msasg.visualstudio.com/DefaultCollecti...
# 34299    https://msasg.visualstudio.com/DefaultCollecti...
# 34301    https://msasg.visualstudio.com/DefaultCollecti...
# 34303    https://msasg.visualstudio.com/DefaultCollecti...
# 34367    https://msasg.visualstudio.com/DefaultCollecti...
# 34370    https://msasg.visualstudio.com/DefaultCollecti...
# 43049    https://msasg.visualstudio.com/DefaultCollecti...
# 43222    https://msasg.visualstudio.com/DefaultCollecti...
# 43226    https://msasg.visualstudio.com/DefaultCollecti...
# 43228    https://msasg.visualstudio.com/DefaultCollecti...
# 43229    https://msasg.visualstudio.com/DefaultCollecti...
# 43230    https://msasg.visualstudio.com/DefaultCollecti...
# 43231    https://msasg.visualstudio.com/DefaultCollecti...
# 43232    https://msasg.visualstudio.com/DefaultCollecti...
# 43233    https://msasg.visualstudio.com/DefaultCollecti...
# 43236    https://msasg.visualstudio.com/DefaultCollecti...
# 43237    https://msasg.visualstudio.com/DefaultCollecti...
# 43239    https://msasg.visualstudio.com/DefaultCollecti...
# 43241    https://msasg.visualstudio.com/DefaultCollecti...
# 43764    https://msasg.visualstudio.com/DefaultCollecti...
# 45333    https://msasg.visualstudio.com/DefaultCollecti...
# ...                                                    ...
# 1038456  https://msasg.visualstudio.com/DefaultCollecti...
# 1038457  https://msasg.visualstudio.com/DefaultCollecti...
# 1038458  https://msasg.visualstudio.com/DefaultCollecti...
# 1038459  https://msasg.visualstudio.com/DefaultCollecti...
# 1038495  https://msasg.visualstudio.com/DefaultCollecti...
# 1038496  https://msasg.visualstudio.com/DefaultCollecti...
# 1038497  https://msasg.visualstudio.com/DefaultCollecti...
# 1038498  https://msasg.visualstudio.com/DefaultCollecti...
# 1038499  https://msasg.visualstudio.com/DefaultCollecti...
# 1038500  https://msasg.visualstudio.com/DefaultCollecti...
# 1038501  https://msasg.visualstudio.com/DefaultCollecti...
# 1038502  https://msasg.visualstudio.com/DefaultCollecti...
# 1038503  https://msasg.visualstudio.com/DefaultCollecti...
# 1038504  https://msasg.visualstudio.com/DefaultCollecti...
# 1038505  https://msasg.visualstudio.com/DefaultCollecti...
# 1038506  https://msasg.visualstudio.com/DefaultCollecti...
# 1038507  https://msasg.visualstudio.com/DefaultCollecti...
# 1038508  https://msasg.visualstudio.com/DefaultCollecti...
# 1039159  https://msasg.visualstudio.com/DefaultCollecti...
# 1047263  https://msasg.visualstudio.com/DefaultCollecti...
# 1048850  https://msasg.visualstudio.com/DefaultCollecti...
# 1048959  https://msasg.visualstudio.com/DefaultCollecti...
# 1052463  https://msasg.visualstudio.com/DefaultCollecti...
# 1056583  https://msasg.visualstudio.com/DefaultCollecti...
# 1057158  https://msasg.visualstudio.com/DefaultCollecti...
# 1058846  https://msasg.visualstudio.com/DefaultCollecti...
# 1065219  https://msasg.visualstudio.com/DefaultCollecti...
# 1066691  https://msasg.visualstudio.com/DefaultCollecti...
# 1068971  https://msasg.visualstudio.com/DefaultCollecti...
# 1069690  https://msasg.visualstudio.com/DefaultCollecti...
#
#         RequirementCollectionDID  \
# 6575                 MS.Security
# 6914                        None
# 6917                        None
# 6936                        None
# 15224                       None
# 15225                       None
# 15937                       None
# 15972                       None
# 21996                       None
# 33656                       None
# 34299                       None
# 34301                       None
# 34303                       None
# 34367                MS.Security
# 34370                MS.Security
# 43049                       None
# 43222                       None
# 43226                       None
# 43228                       None
# 43229                       None
# 43230                       None
# 43231                       None
# 43232                       None
# 43233                       None
# 43236                       None
# 43237                       None
# 43239                       None
# 43241                       None
# 43764                       None
# 45333                       None
# ...                          ...
# 1038456              MS.Security
# 1038457              MS.Security
# 1038458              MS.Security
# 1038459              MS.Security
# 1038495              MS.Security
# 1038496              MS.Security
# 1038497              MS.Security
# 1038498              MS.Security
# 1038499              MS.Security
# 1038500              MS.Security
# 1038501              MS.Security
# 1038502              MS.Security
# 1038503              MS.Security
# 1038504              MS.Security
# 1038505              MS.Security
# 1038506              MS.Security
# 1038507              MS.Security
# 1038508              MS.Security
# 1039159              MS.Security
# 1047263              MS.Security
# 1048850                     None
# 1048959              MS.Security
# 1052463                     None
# 1056583                     None
# 1057158              MS.Security
# 1058846                     None
# 1065219              MS.Security
# 1066691                     None
# 1068971                     None
# 1069690                     None
#
#                                                    No Urls  \
# 6575     (Via External Team) Verify Decryption is Worki...
# 6914     *RELEASE BLOCKER* - Secret not working between...
# 6917     *RELEASE BLOCKER* Add secret token communicati...
# 6936     *RELEASE BLOCKER* Setup secret between SNR/XAP...
# 15224    [ MSASG_AdsCX_retail ][ CodeAnalysis ] - Defec...
# 15225    [ MSASG_AdsCX_retail ][ CodeAnalysis ] - Defec...
# 15937    [ MSASG_Agilemining-Packages_retail ][ CodeAna...
# 15972    [ MSASG_AnB_retail ][ CodeAnalysis ] - Defect ...
# 21996    [ MSASG_Indexquality_Malware_Prod_retail ][ Co...
# 33656    [ Scheduling] Setting up Secure Service Fabric...
# 34299    [#004890] BingAds - Unsafe SSL TrustManager De...
# 34301    [#006062] Insecure Random Number Generator Usage
# 34303    [#006741] - Insecure Random Number Generator U...
# 34367    [@Work] Address issues identified by static co...
# 34370    [@Work] Classify and handle source code and da...
# 43049    [AE365] Merge code from Aether to AE365 - Secu...
# 43222                          [AetherSecure] Add Counters
# 43226                    [AetherSecure] Fix Cache Deletion
# 43228                       [AetherSecure] GC for Services
# 43229         [AetherSecure] Health Checker for ExeWorkers
# 43230             [AetherSecure] Implement GC for Services
# 43231    [AetherSecure] Investigate Cache Deletion Fail...
# 43232      [AetherSecure] Investigate HealthChecker Issues
# 43233               [AetherSecure] Investigate Memory Leak
# 43236          [AetherSecure] Machines Availability Issues
# 43237                 [AetherSecure] Random FolderName Fix
# 43239         [AetherSecure] Show Realtime STDOut/Err Link
# 43241      [AetherSecure] Test & Deploy New SocialAccessor
# 43764    [Agora Crash][]: MainPage: client_GetNavInfoCo...
# 45333    [Analysis] Use Login IP from CCUI for PI Fraud...
# ...                                                    ...
# 1038456  Verify that Shared Access Signatures (SAS) are...
# 1038457  Verify that Shared Access Signatures (SAS) are...
# 1038458  Verify that Shared Access Signatures (SAS) are...
# 1038459  Verify that Shared Access Signatures (SAS) are...
# 1038495  Verify the appropriate Microsoft Account Ident...
# 1038496  Verify the appropriate Microsoft Account Ident...
# 1038497  Verify the appropriate Microsoft Account Ident...
# 1038498  Verify the appropriate Microsoft Account Ident...
# 1038499  Verify the appropriate Microsoft Account Ident...
# 1038500  Verify the appropriate Microsoft Account Ident...
# 1038501  Verify the appropriate Microsoft Account Ident...
# 1038502  Verify the appropriate Microsoft Account Ident...
# 1038503  Verify the appropriate Microsoft Account Ident...
# 1038504  Verify the appropriate Microsoft Account Ident...
# 1038505  Verify the appropriate Microsoft Account Ident...
# 1038506  Verify the appropriate Microsoft Account Ident...
# 1038507  Verify the appropriate Microsoft Account Ident...
# 1038508  Verify the appropriate Microsoft Account Ident...
# 1039159  Very Nice App, I like app, Just 5 min. of use ...
# 1047263                 Virus scan blocking files on agent
# 1048850                       VS Plugins for Secure Coding
# 1048959               VSOHelper should decrypt config last
# 1052463    Weekly Recall Analysis for Phishing Escalations
# 1056583                                 WLSP Phishing data
# 1057158  Work with IRMC PMO team to discover their fram...
# 1058846  Working Set + Latency Stream: BondModelFactory...
# 1065219    Write the playbook for PrivSec Breach Scenarios
# 1066691  XAP: Enable secure traffic between Bing and Ya...
# 1068971                XSS on routes with query parameters
# 1069690  You almost gave me a heart attack. You showed ...
#
#                                                   No Paths  \
# 6575     (Via External Team) Verify Decryption is Worki...
# 6914     *RELEASE BLOCKER* - Secret not working between...
# 6917     *RELEASE BLOCKER* Add secret token communicati...
# 6936     *RELEASE BLOCKER* Setup secret between SNR/XAP...
# 15224    [ MSASG_AdsCX_retail ][ CodeAnalysis ] - Defec...
# 15225    [ MSASG_AdsCX_retail ][ CodeAnalysis ] - Defec...
# 15937    [ MSASG_Agilemining-Packages_retail ][ CodeAna...
# 15972    [ MSASG_AnB_retail ][ CodeAnalysis ] - Defect ...
# 21996    [ MSASG_Indexquality_Malware_Prod_retail ][ Co...
# 33656    [ Scheduling] Setting up Secure Service Fabric...
# 34299    [#004890] BingAds - Unsafe SSL TrustManager De...
# 34301    [#006062] Insecure Random Number Generator Usage
# 34303    [#006741] - Insecure Random Number Generator U...
# 34367    [@Work] Address issues identified by static co...
# 34370    [@Work] Classify and handle source code and da...
# 43049    [AE365] Merge code from Aether to AE365 - Secu...
# 43222                          [AetherSecure] Add Counters
# 43226                    [AetherSecure] Fix Cache Deletion
# 43228                       [AetherSecure] GC for Services
# 43229         [AetherSecure] Health Checker for ExeWorkers
# 43230             [AetherSecure] Implement GC for Services
# 43231    [AetherSecure] Investigate Cache Deletion Fail...
# 43232      [AetherSecure] Investigate HealthChecker Issues
# 43233               [AetherSecure] Investigate Memory Leak
# 43236          [AetherSecure] Machines Availability Issues
# 43237                 [AetherSecure] Random FolderName Fix
# 43239         [AetherSecure] Show Realtime STDOut/Err Link
# 43241      [AetherSecure] Test & Deploy New SocialAccessor
# 43764    [Agora Crash][]: MainPage: client_GetNavInfoCo...
# 45333    [Analysis] Use Login IP from CCUI for PI Fraud...
# ...                                                    ...
# 1038456  Verify that Shared Access Signatures (SAS) are...
# 1038457  Verify that Shared Access Signatures (SAS) are...
# 1038458  Verify that Shared Access Signatures (SAS) are...
# 1038459  Verify that Shared Access Signatures (SAS) are...
# 1038495  Verify the appropriate Microsoft Account Ident...
# 1038496  Verify the appropriate Microsoft Account Ident...
# 1038497  Verify the appropriate Microsoft Account Ident...
# 1038498  Verify the appropriate Microsoft Account Ident...
# 1038499  Verify the appropriate Microsoft Account Ident...
# 1038500  Verify the appropriate Microsoft Account Ident...
# 1038501  Verify the appropriate Microsoft Account Ident...
# 1038502  Verify the appropriate Microsoft Account Ident...
# 1038503  Verify the appropriate Microsoft Account Ident...
# 1038504  Verify the appropriate Microsoft Account Ident...
# 1038505  Verify the appropriate Microsoft Account Ident...
# 1038506  Verify the appropriate Microsoft Account Ident...
# 1038507  Verify the appropriate Microsoft Account Ident...
# 1038508  Verify the appropriate Microsoft Account Ident...
# 1039159  Very Nice App, I like app, Just 5 min. of use ...
# 1047263                 Virus scan blocking files on agent
# 1048850                       VS Plugins for Secure Coding
# 1048959               VSOHelper should decrypt config last
# 1052463    Weekly Recall Analysis for Phishing Escalations
# 1056583                                 WLSP Phishing data
# 1057158  Work with IRMC PMO team to discover their fram...
# 1058846  Working Set + Latency Stream: BondModelFactory...
# 1065219    Write the playbook for PrivSec Breach Scenarios
# 1066691  XAP: Enable secure traffic between Bing and Ya...
# 1068971                XSS on routes with query parameters
# 1069690  You almost gave me a heart attack. You showed ...
#
#                                         No Links and Paths  \
# 6575     (Via External Team) Verify Decryption is Worki...
# 6914     *RELEASE BLOCKER* - Secret not working between...
# 6917     *RELEASE BLOCKER* Add secret token communicati...
# 6936     *RELEASE BLOCKER* Setup secret between and rem...
# 15224    [ MSASG_AdsCX_retail ][ CodeAnalysis ] - Defec...
# 15225    [ MSASG_AdsCX_retail ][ CodeAnalysis ] - Defec...
# 15937    [ MSASG_Agilemining-Packages_retail ][ CodeAna...
# 15972    [ MSASG_AnB_retail ][ CodeAnalysis ] - Defect ...
# 21996    [ MSASG_Indexquality_Malware_Prod_retail ][ Co...
# 33656    [ Scheduling] Setting up Secure Service Fabric...
# 34299    [#004890] BingAds - Unsafe SSL TrustManager De...
# 34301     [#006062] Insecure Random Number Generator Usage
# 34303    [#006741] - Insecure Random Number Generator U...
# 34367    [@Work] Address issues identified by static co...
# 34370    [@Work] Classify and handle source code and da...
# 43049    [AE365] Merge code from Aether to AE365 - Secu...
# 43222                          [AetherSecure] Add Counters
# 43226                    [AetherSecure] Fix Cache Deletion
# 43228                       [AetherSecure] GC for Services
# 43229         [AetherSecure] Health Checker for ExeWorkers
# 43230             [AetherSecure] Implement GC for Services
# 43231    [AetherSecure] Investigate Cache Deletion Fail...
# 43232      [AetherSecure] Investigate HealthChecker Issues
# 43233               [AetherSecure] Investigate Memory Leak
# 43236          [AetherSecure] Machines Availability Issues
# 43237                 [AetherSecure] Random FolderName Fix
# 43239                    [AetherSecure] Show Realtime Link
# 43241      [AetherSecure] Test & Deploy New SocialAccessor
# 43764    [Agora Crash][]: MainPage: client_GetNavInfoCo...
# 45333    [Analysis] Use Login IP from CCUI for PI Fraud...
# ...                                                    ...
# 1038456  Verify that Shared Access Signatures (SAS) are...
# 1038457  Verify that Shared Access Signatures (SAS) are...
# 1038458  Verify that Shared Access Signatures (SAS) are...
# 1038459  Verify that Shared Access Signatures (SAS) are...
# 1038495  Verify the appropriate Microsoft Account Ident...
# 1038496  Verify the appropriate Microsoft Account Ident...
# 1038497  Verify the appropriate Microsoft Account Ident...
# 1038498  Verify the appropriate Microsoft Account Ident...
# 1038499  Verify the appropriate Microsoft Account Ident...
# 1038500  Verify the appropriate Microsoft Account Ident...
# 1038501  Verify the appropriate Microsoft Account Ident...
# 1038502  Verify the appropriate Microsoft Account Ident...
# 1038503  Verify the appropriate Microsoft Account Ident...
# 1038504  Verify the appropriate Microsoft Account Ident...
# 1038505  Verify the appropriate Microsoft Account Ident...
# 1038506  Verify the appropriate Microsoft Account Ident...
# 1038507  Verify the appropriate Microsoft Account Ident...
# 1038508  Verify the appropriate Microsoft Account Ident...
# 1039159  Very Nice App, I like app, Just 5 min. of use ...
# 1047263                 Virus scan blocking files on agent
# 1048850                       VS Plugins for Secure Coding
# 1048959               VSOHelper should decrypt config last
# 1052463    Weekly Recall Analysis for Phishing Escalations
# 1056583                                 WLSP Phishing data
# 1057158  Work with IRMC PMO team to discover their fram...
# 1058846  Working Set + Latency Stream: BondModelFactory...
# 1065219    Write the playbook for PrivSec Breach Scenarios
# 1066691  XAP: Enable secure traffic between Bing and Ya...
# 1068971                XSS on routes with query parameters
# 1069690  You almost gave me a heart attack. You showed ...
#
#                                                Split Upper  \
# 6575     ( Via  External  Team)  Verify  Decryption is ...
# 6914     *RELEASE BLOCKER* -  Secret not working betwee...
# 6917     *RELEASE BLOCKER*  Add secret token communicat...
# 6936     *RELEASE BLOCKER*  Setup secret between and re...
# 15224    [ MSASG_ Ads CX_retail ][  Code Analysis ] -  ...
# 15225    [ MSASG_ Ads CX_retail ][  Code Analysis ] -  ...
# 15937    [ MSASG_ Agilemining- Packages_retail ][  Code...
# 15972    [ MSASG_ An B_retail ][  Code Analysis ] -  De...
# 21996    [ MSASG_ Indexquality_ Malware_ Prod_retail ][...
# 33656    [  Scheduling]  Setting up  Secure  Service  F...
# 34299    [#004890]  Bing Ads -  Unsafe SSL  Trust Manag...
# 34301    [#006062]  Insecure  Random  Number  Generator...
# 34303    [#006741] -  Insecure  Random  Number  Generat...
# 34367    [@ Work]  Address issues identified by static ...
# 34370    [@ Work]  Classify and handle source code and ...
# 43049    [AE365]  Merge code from  Aether to AE365 -  S...
# 43222                      [ Aether Secure]  Add  Counters
# 43226               [ Aether Secure]  Fix  Cache  Deletion
# 43228                    [ Aether Secure] GC for  Services
# 43229    [ Aether Secure]  Health  Checker for  Exe Wor...
# 43230         [ Aether Secure]  Implement GC for  Services
# 43231    [ Aether Secure]  Investigate  Cache  Deletion...
# 43232    [ Aether Secure]  Investigate  Health Checker ...
# 43233          [ Aether Secure]  Investigate  Memory  Leak
# 43236     [ Aether Secure]  Machines  Availability  Issues
# 43237           [ Aether Secure]  Random  Folder Name  Fix
# 43239               [ Aether Secure]  Show  Realtime  Link
# 43241    [ Aether Secure]  Test &  Deploy  New  Social ...
# 43764    [ Agora  Crash][]:  Main Page: client_ Get Nav...
# 45333    [ Analysis]  Use  Login IP from CCUI for PI  F...
# ...                                                    ...
# 1038456  Verify that  Shared  Access  Signatures (SAS) ...
# 1038457  Verify that  Shared  Access  Signatures (SAS) ...
# 1038458  Verify that  Shared  Access  Signatures (SAS) ...
# 1038459  Verify that  Shared  Access  Signatures (SAS) ...
# 1038495  Verify the appropriate  Microsoft  Account  Id...
# 1038496  Verify the appropriate  Microsoft  Account  Id...
# 1038497  Verify the appropriate  Microsoft  Account  Id...
# 1038498  Verify the appropriate  Microsoft  Account  Id...
# 1038499  Verify the appropriate  Microsoft  Account  Id...
# 1038500  Verify the appropriate  Microsoft  Account  Id...
# 1038501  Verify the appropriate  Microsoft  Account  Id...
# 1038502  Verify the appropriate  Microsoft  Account  Id...
# 1038503  Verify the appropriate  Microsoft  Account  Id...
# 1038504  Verify the appropriate  Microsoft  Account  Id...
# 1038505  Verify the appropriate  Microsoft  Account  Id...
# 1038506  Verify the appropriate  Microsoft  Account  Id...
# 1038507  Verify the appropriate  Microsoft  Account  Id...
# 1038508  Verify the appropriate  Microsoft  Account  Id...
# 1039159  Very  Nice  App, I like app,  Just 5 min. of u...
# 1047263                 Virus scan blocking files on agent
# 1048850                    VS  Plugins for  Secure  Coding
# 1048959              VSO Helper should decrypt config last
# 1052463  Weekly  Recall  Analysis for  Phishing  Escala...
# 1056583                                WLSP  Phishing data
# 1057158  Work with IRMC PMO team to discover their fram...
# 1058846  Working  Set +  Latency  Stream:  Bond Model F...
# 1065219  Write the playbook for  Priv Sec  Breach  Scen...
# 1066691  XAP:  Enable secure traffic between  Bing and ...
# 1068971                XSS on routes with query parameters
# 1069690  You almost gave me a heart attack.  You showed...
#
#                                             No Punctuation  \
# 6575     Via External Team Verify Decryption is Working...
# 6914     RELEASE BLOCKER Secret not working between Fal...
# 6917     RELEASE BLOCKER Add secret token communication...
# 6936     RELEASE BLOCKER Setup secret between and remov...
# 15224    MSASG Ads CX retail Code Analysis Defect Revie...
# 15225    MSASG Ads CX retail Code Analysis Defect Revie...
# 15937    MSASG Agilemining Packages retail Code Analysi...
# 15972    MSASG An B retail Code Analysis Defect Transpa...
# 21996    MSASG Indexquality Malware Prod retail Code An...
# 33656    Scheduling Setting up Secure Service Fabric Cl...
# 34299     004890 Bing Ads Unsafe SSL Trust Manager Defined
# 34301        006062 Insecure Random Number Generator Usage
# 34303        006741 Insecure Random Number Generator Usage
# 34367    Work Address issues identified by static code ...
# 34370    Work Classify and handle source code and data ...
# 43049    AE365 Merge code from Aether to AE365 Secure A...
# 43222                           Aether Secure Add Counters
# 43226                     Aether Secure Fix Cache Deletion
# 43228                        Aether Secure GC for Services
# 43229         Aether Secure Health Checker for Exe Workers
# 43230              Aether Secure Implement GC for Services
# 43231    Aether Secure Investigate Cache Deletion Failures
# 43232      Aether Secure Investigate Health Checker Issues
# 43233                Aether Secure Investigate Memory Leak
# 43236           Aether Secure Machines Availability Issues
# 43237                 Aether Secure Random Folder Name Fix
# 43239                     Aether Secure Show Realtime Link
# 43241        Aether Secure Test Deploy New Social Accessor
# 43764    Agora Crash Main Page client Get Nav Info Comp...
# 45333    Analysis Use Login IP from CCUI for PI Fraud P...
# ...                                                    ...
# 1038456  Verify that Shared Access Signatures SAS are b...
# 1038457  Verify that Shared Access Signatures SAS are b...
# 1038458  Verify that Shared Access Signatures SAS are b...
# 1038459  Verify that Shared Access Signatures SAS are b...
# 1038495  Verify the appropriate Microsoft Account Ident...
# 1038496  Verify the appropriate Microsoft Account Ident...
# 1038497  Verify the appropriate Microsoft Account Ident...
# 1038498  Verify the appropriate Microsoft Account Ident...
# 1038499  Verify the appropriate Microsoft Account Ident...
# 1038500  Verify the appropriate Microsoft Account Ident...
# 1038501  Verify the appropriate Microsoft Account Ident...
# 1038502  Verify the appropriate Microsoft Account Ident...
# 1038503  Verify the appropriate Microsoft Account Ident...
# 1038504  Verify the appropriate Microsoft Account Ident...
# 1038505  Verify the appropriate Microsoft Account Ident...
# 1038506  Verify the appropriate Microsoft Account Ident...
# 1038507  Verify the appropriate Microsoft Account Ident...
# 1038508  Verify the appropriate Microsoft Account Ident...
# 1039159  Very Nice App I like app Just 5 min of use ple...
# 1047263                 Virus scan blocking files on agent
# 1048850                       VS Plugins for Secure Coding
# 1048959              VSO Helper should decrypt config last
# 1052463    Weekly Recall Analysis for Phishing Escalations
# 1056583                                 WLSP Phishing data
# 1057158  Work with IRMC PMO team to discover their fram...
# 1058846  Working Set Latency Stream Bond Model Factory ...
# 1065219   Write the playbook for Priv Sec Breach Scenarios
# 1066691  XAP Enable secure traffic between Bing and Yah...
# 1068971                XSS on routes with query parameters
# 1069690  You almost gave me a heart attack You showed t...
#
#                                                Clean Title  Predictions  \
# 6575     Via External Team Verify Decryption is Working...         True
# 6914     RELEASE BLOCKER Secret not working between Fal...         True
# 6917     RELEASE BLOCKER Add secret token communication...         True
# 6936     RELEASE BLOCKER Setup secret between and remov...         True
# 15224    MSASG Ads CX retail Code Analysis Defect Revie...        False
# 15225    MSASG Ads CX retail Code Analysis Defect Revie...        False
# 15937    MSASG Agilemining Packages retail Code Analysi...        False
# 15972    MSASG An B retail Code Analysis Defect Transpa...        False
# 21996    MSASG Indexquality Malware Prod retail Code An...         True
# 33656    Scheduling Setting up Secure Service Fabric Cl...         True
# 34299     004890 Bing Ads Unsafe SSL Trust Manager Defined         True
# 34301        006062 Insecure Random Number Generator Usage         True
# 34303        006741 Insecure Random Number Generator Usage         True
# 34367    Work Address issues identified by static code ...         True
# 34370    Work Classify and handle source code and data ...         True
# 43049    AE365 Merge code from Aether to AE365 Secure A...         True
# 43222                           Aether Secure Add Counters        False
# 43226                     Aether Secure Fix Cache Deletion        False
# 43228                        Aether Secure GC for Services        False
# 43229         Aether Secure Health Checker for Exe Workers        False
# 43230              Aether Secure Implement GC for Services        False
# 43231    Aether Secure Investigate Cache Deletion Failures        False
# 43232      Aether Secure Investigate Health Checker Issues        False
# 43233                Aether Secure Investigate Memory Leak        False
# 43236           Aether Secure Machines Availability Issues        False
# 43237                 Aether Secure Random Folder Name Fix        False
# 43239                     Aether Secure Show Realtime Link        False
# 43241        Aether Secure Test Deploy New Social Accessor        False
# 43764    Agora Crash Main Page client Get Nav Info Comp...        False
# 45333    Analysis Use Login IP from CCUI for PI Fraud P...        False
# ...                                                    ...          ...
# 1038456  Verify that Shared Access Signatures SAS are b...         True
# 1038457  Verify that Shared Access Signatures SAS are b...         True
# 1038458  Verify that Shared Access Signatures SAS are b...         True
# 1038459  Verify that Shared Access Signatures SAS are b...         True
# 1038495  Verify the appropriate Microsoft Account Ident...         True
# 1038496  Verify the appropriate Microsoft Account Ident...         True
# 1038497  Verify the appropriate Microsoft Account Ident...         True
# 1038498  Verify the appropriate Microsoft Account Ident...         True
# 1038499  Verify the appropriate Microsoft Account Ident...         True
# 1038500  Verify the appropriate Microsoft Account Ident...         True
# 1038501  Verify the appropriate Microsoft Account Ident...         True
# 1038502  Verify the appropriate Microsoft Account Ident...         True
# 1038503  Verify the appropriate Microsoft Account Ident...         True
# 1038504  Verify the appropriate Microsoft Account Ident...         True
# 1038505  Verify the appropriate Microsoft Account Ident...         True
# 1038506  Verify the appropriate Microsoft Account Ident...         True
# 1038507  Verify the appropriate Microsoft Account Ident...         True
# 1038508  Verify the appropriate Microsoft Account Ident...         True
# 1039159  Very Nice App I like app Just min of use pleas...         True
# 1047263                 Virus scan blocking files on agent        False
# 1048850                       VS Plugins for Secure Coding         True
# 1048959              VSO Helper should decrypt config last        False
# 1052463    Weekly Recall Analysis for Phishing Escalations        False
# 1056583                                 WLSP Phishing data        False
# 1057158  Work with IRMC PMO team to discover their fram...         True
# 1058846  Working Set Latency Stream Bond Model Factory ...         True
# 1065219   Write the playbook for Priv Sec Breach Scenarios         True
# 1066691  XAP Enable secure traffic between Bing and Yah...         True
# 1068971                XSS on routes with query parameters         True
# 1069690  You almost gave me a heart attack You showed t...         True
#
#          Pred_Proba0  Pred_Proba1  Predictions_fewTypes  Pred_Proba0_fewTypes  \
# 6575        0.042940     0.957060                 False              0.997046
# 6914        0.395128     0.604872                 False              0.635401
# 6917        0.345625     0.654375                 False              0.561229
# 6936        0.490574     0.509426                 False              0.683140
# 15224       0.681045     0.318955                  True              0.448253
# 15225       0.681045     0.318955                  True              0.448253
# 15937       0.606666     0.393334                  True              0.458998
# 15972       0.515939     0.484061                  True              0.261921
# 21996       0.490204     0.509796                 False              0.772613
# 33656       0.395672     0.604328                 False              0.500516
# 34299       0.083224     0.916776                 False              0.508674
# 34301       0.316030     0.683970                 False              0.636383
# 34303       0.316030     0.683970                 False              0.636383
# 34367       0.415293     0.584707                 False              0.969708
# 34370       0.361255     0.638745                 False              0.995364
# 43049       0.460602     0.539398                 False              0.614566
# 43222       0.558630     0.441370                  True              0.100308
# 43226       0.526491     0.473509                  True              0.161134
# 43228       0.522082     0.477918                  True              0.041442
# 43229       0.808469     0.191531                  True              0.474227
# 43230       0.561009     0.438991                  True              0.134861
# 43231       0.720268     0.279732                  True              0.405079
# 43232       0.687140     0.312860                  True              0.448566
# 43233       0.661377     0.338623                  True              0.183640
# 43236       0.750500     0.249500                  True              0.141948
# 43237       0.514298     0.485702                  True              0.221996
# 43239       0.686824     0.313176                  True              0.249253
# 43241       0.574845     0.425155                  True              0.372730
# 43764       0.614849     0.385151                  True              0.342499
# 45333       0.988573     0.011427                  True              0.179395
# ...              ...          ...                   ...                   ...
# 1038456     0.492111     0.507889                 False              0.989937
# 1038457     0.492111     0.507889                 False              0.989937
# 1038458     0.492111     0.507889                 False              0.989937
# 1038459     0.492111     0.507889                 False              0.989937
# 1038495     0.417472     0.582528                 False              0.988382
# 1038496     0.417472     0.582528                 False              0.988382
# 1038497     0.417472     0.582528                 False              0.988382
# 1038498     0.417472     0.582528                 False              0.988382
# 1038499     0.417472     0.582528                 False              0.988382
# 1038500     0.417472     0.582528                 False              0.988382
# 1038501     0.417472     0.582528                 False              0.988382
# 1038502     0.417472     0.582528                 False              0.988382
# 1038503     0.417472     0.582528                 False              0.988382
# 1038504     0.417472     0.582528                 False              0.988382
# 1038505     0.417472     0.582528                 False              0.988382
# 1038506     0.417472     0.582528                 False              0.988382
# 1038507     0.417472     0.582528                 False              0.988382
# 1038508     0.417472     0.582528                 False              0.988382
# 1039159     0.088004     0.911996                 False              0.502904
# 1047263     0.969206     0.030794                  True              0.005220
# 1048850     0.205979     0.794021                 False              0.685709
# 1048959     0.992434     0.007566                  True              0.024560
# 1052463     0.998695     0.001305                  True              0.064397
# 1056583     0.994452     0.005548                  True              0.011882
# 1057158     0.084926     0.915074                 False              0.994903
# 1058846     0.488254     0.511746                 False              0.562061
# 1065219     0.023746     0.976254                 False              0.992700
# 1066691     0.383239     0.616761                 False              0.883979
# 1068971     0.481731     0.518269                 False              0.545815
# 1069690     0.439763     0.560237                 False              0.633679
#
#          Pred_Proba1_fewTypes
# 6575                 0.002954
# 6914                 0.364599
# 6917                 0.438771
# 6936                 0.316860
# 15224                0.551747
# 15225                0.551747
# 15937                0.541002
# 15972                0.738079
# 21996                0.227387
# 33656                0.499484
# 34299                0.491326
# 34301                0.363617
# 34303                0.363617
# 34367                0.030292
# 34370                0.004636
# 43049                0.385434
# 43222                0.899692
# 43226                0.838866
# 43228                0.958558
# 43229                0.525773
# 43230                0.865139
# 43231                0.594921
# 43232                0.551434
# 43233                0.816360
# 43236                0.858052
# 43237                0.778004
# 43239                0.750747
# 43241                0.627270
# 43764                0.657501
# 45333                0.820605
# ...                       ...
# 1038456              0.010063
# 1038457              0.010063
# 1038458              0.010063
# 1038459              0.010063
# 1038495              0.011618
# 1038496              0.011618
# 1038497              0.011618
# 1038498              0.011618
# 1038499              0.011618
# 1038500              0.011618
# 1038501              0.011618
# 1038502              0.011618
# 1038503              0.011618
# 1038504              0.011618
# 1038505              0.011618
# 1038506              0.011618
# 1038507              0.011618
# 1038508              0.011618
# 1039159              0.497096
# 1047263              0.994780
# 1048850              0.314291
# 1048959              0.975440
# 1052463              0.935603
# 1056583              0.988118
# 1057158              0.005097
# 1058846              0.437939
# 1065219              0.007300
# 1066691              0.116021
# 1068971              0.454185
# 1069690              0.366321
#
# [1817 rows x 15 columns]

# %%
msasg_data.columns
# Out:
# Index(['Title', 'SourceLink', 'RequirementCollectionDID', 'No Urls',
#        'No Paths', 'No Links and Paths', 'Split Upper', 'No Punctuation',
#        'Clean Title', 'Predictions', 'Pred_Proba0', 'Pred_Proba1',
#        'Predictions_fewTypes', 'Pred_Proba0_fewTypes', 'Pred_Proba1_fewTypes'],
#       dtype='object')

# %%
msasg_data[msasg_data['Predictions'] != msasg_data['Predictions_fewTypes']][['Title', 'SourceLink', 
                                                                             'RequirementCollectionDID', 
                                                                             'Predictions', 
                                                                             'Pred_Proba0', 'Pred_Proba1',
                                                                             'Predictions_fewTypes', 
                                                                             'Pred_Proba0_fewTypes', 
                                                                             'Pred_Proba1_fewTypes']].to_csv('msasg titles where both models disagree on prediction.csv')

# %%
msasg_data[msasg_data['Predictions'] != msasg_data['Predictions_fewTypes']][['Clean Title', 'Predictions','Predictions_fewTypes']].sort()
# Out:
#                                                Clean Title  Predictions  \
# 6575     Via External Team Verify Decryption is Working...         True
# 6914     RELEASE BLOCKER Secret not working between Fal...         True
# 6917     RELEASE BLOCKER Add secret token communication...         True
# 6936     RELEASE BLOCKER Setup secret between and remov...         True
# 15224    MSASG Ads CX retail Code Analysis Defect Revie...        False
# 15225    MSASG Ads CX retail Code Analysis Defect Revie...        False
# 15937    MSASG Agilemining Packages retail Code Analysi...        False
# 15972    MSASG An B retail Code Analysis Defect Transpa...        False
# 21996    MSASG Indexquality Malware Prod retail Code An...         True
# 33656    Scheduling Setting up Secure Service Fabric Cl...         True
# 34299     004890 Bing Ads Unsafe SSL Trust Manager Defined         True
# 34301        006062 Insecure Random Number Generator Usage         True
# 34303        006741 Insecure Random Number Generator Usage         True
# 34367    Work Address issues identified by static code ...         True
# 34370    Work Classify and handle source code and data ...         True
# 43049    AE365 Merge code from Aether to AE365 Secure A...         True
# 43222                           Aether Secure Add Counters        False
# 43226                     Aether Secure Fix Cache Deletion        False
# 43228                        Aether Secure GC for Services        False
# 43229         Aether Secure Health Checker for Exe Workers        False
# 43230              Aether Secure Implement GC for Services        False
# 43231    Aether Secure Investigate Cache Deletion Failures        False
# 43232      Aether Secure Investigate Health Checker Issues        False
# 43233                Aether Secure Investigate Memory Leak        False
# 43236           Aether Secure Machines Availability Issues        False
# 43237                 Aether Secure Random Folder Name Fix        False
# 43239                     Aether Secure Show Realtime Link        False
# 43241        Aether Secure Test Deploy New Social Accessor        False
# 43764    Agora Crash Main Page client Get Nav Info Comp...        False
# 45333    Analysis Use Login IP from CCUI for PI Fraud P...        False
# ...                                                    ...          ...
# 1038456  Verify that Shared Access Signatures SAS are b...         True
# 1038457  Verify that Shared Access Signatures SAS are b...         True
# 1038458  Verify that Shared Access Signatures SAS are b...         True
# 1038459  Verify that Shared Access Signatures SAS are b...         True
# 1038495  Verify the appropriate Microsoft Account Ident...         True
# 1038496  Verify the appropriate Microsoft Account Ident...         True
# 1038497  Verify the appropriate Microsoft Account Ident...         True
# 1038498  Verify the appropriate Microsoft Account Ident...         True
# 1038499  Verify the appropriate Microsoft Account Ident...         True
# 1038500  Verify the appropriate Microsoft Account Ident...         True
# 1038501  Verify the appropriate Microsoft Account Ident...         True
# 1038502  Verify the appropriate Microsoft Account Ident...         True
# 1038503  Verify the appropriate Microsoft Account Ident...         True
# 1038504  Verify the appropriate Microsoft Account Ident...         True
# 1038505  Verify the appropriate Microsoft Account Ident...         True
# 1038506  Verify the appropriate Microsoft Account Ident...         True
# 1038507  Verify the appropriate Microsoft Account Ident...         True
# 1038508  Verify the appropriate Microsoft Account Ident...         True
# 1039159  Very Nice App I like app Just min of use pleas...         True
# 1047263                 Virus scan blocking files on agent        False
# 1048850                       VS Plugins for Secure Coding         True
# 1048959              VSO Helper should decrypt config last        False
# 1052463    Weekly Recall Analysis for Phishing Escalations        False
# 1056583                                 WLSP Phishing data        False
# 1057158  Work with IRMC PMO team to discover their fram...         True
# 1058846  Working Set Latency Stream Bond Model Factory ...         True
# 1065219   Write the playbook for Priv Sec Breach Scenarios         True
# 1066691  XAP Enable secure traffic between Bing and Yah...         True
# 1068971                XSS on routes with query parameters         True
# 1069690  You almost gave me a heart attack You showed t...         True
#
#          Predictions_fewTypes
# 6575                    False
# 6914                    False
# 6917                    False
# 6936                    False
# 15224                    True
# 15225                    True
# 15937                    True
# 15972                    True
# 21996                   False
# 33656                   False
# 34299                   False
# 34301                   False
# 34303                   False
# 34367                   False
# 34370                   False
# 43049                   False
# 43222                    True
# 43226                    True
# 43228                    True
# 43229                    True
# 43230                    True
# 43231                    True
# 43232                    True
# 43233                    True
# 43236                    True
# 43237                    True
# 43239                    True
# 43241                    True
# 43764                    True
# 45333                    True
# ...                       ...
# 1038456                 False
# 1038457                 False
# 1038458                 False
# 1038459                 False
# 1038495                 False
# 1038496                 False
# 1038497                 False
# 1038498                 False
# 1038499                 False
# 1038500                 False
# 1038501                 False
# 1038502                 False
# 1038503                 False
# 1038504                 False
# 1038505                 False
# 1038506                 False
# 1038507                 False
# 1038508                 False
# 1039159                 False
# 1047263                  True
# 1048850                 False
# 1048959                  True
# 1052463                  True
# 1056583                  True
# 1057158                 False
# 1058846                 False
# 1065219                 False
# 1066691                 False
# 1068971                 False
# 1069690                 False
#
# [1817 rows x 3 columns]

# %%
[True for word in 'Aether Secure Implement GC for Services'.lower().split() if word in vocab_12]
# Out:
# [True, True, True, True, True]

# %%
msasg_data.sort_values(['Clean Title'],ascending = True)
# Out:
#                                                     Title  \
# 7081                                              //Build
# 278811                                                 {}
# 278810                                                 {}
# 278809                                                 {}
# 278808                                                 {}
# 278807                                                 {}
# 278806                                                 {}
# 278805                                                 {}
# 278804                                                 {}
# 278803                                                 {}
# 278802                                                 {}
# 278801                                                 {}
# 278800                                                 {}
# 824015                                         Open/Close
# 824014                                         Open/Close
# 278812                                                 {}
# 824013                                         Open/Close
# 254614  [TestFailure][SI][BVT][11/28/2017]HotelCenter_...
# 278799                                                 {}
# 278798                                                 {}
# 742967                                       Logs/Metrics
# 742688                                Logging/Diagnostics
# 695353                                        List/Search
# 278797                                                 {}
# 255842  [ThresholdPC][Proactive][个人信息][最喜爱的地方]:编辑收藏夹地址...
# 278796                                                 {}
# 823363                                          OOBE/FTUE
# 278795                                                 {}
# 466438                                         CR/testing
# 466437                                         CR/Testing
# ...                                                   ...
# 1736        🍩 Landscape (and arbitrary size) mode support
# 1789    🍩 Move photo client-side filters (colors, lamd...
# 1826                              🍩 Open items (S4L Team)
# 1827                        🍩 Open items (Sprinkles Team)
# 1839    🍩 PM: Branding -- something Jamil should follo...
# 1840    🍩 PM: CELA pass – combined across bing and sky...
# 1834    🍩 Performance, multiple-calls, thread-safety, ...
# 1975               🍩 Sticker Service: Photo frame support
# 1976                   🍩 Sticker Service: Weather Sticker
# 1744    🍩 Live-site/production readiness ⛑(tests, xpin...
# 698                                                     👌
# 699                                                     👍
# 1477                                  💎 Camera As Input 📸
# 1544                                        💎 Detail Page
# 875                     💎 [Diamond MVP]: Explore/Trending
# 876      💎 [Diamond MVP]: Initial User Interest Settings
# 877     💎 [Diamond MVP]: My Account (Saves, Profile, S...
# 878     💎 [Diamond MVP]: Personalized Feed (Daily Dige...
# 879     💎 [Diamond MVP]: Process Related (Daily Build,...
# 880     💎 [Diamond MVP]: User Sign In (Facebook, Micro...
# 1569                      💎 Enable Hockey App (with Paul)
# 1604                                     💎 Favorites page
# 1629                                            💎 General
# 1663                      💎 Image App: Navigation/Tabbing
# 1664    💎 Image App: Sign In (Pending shared control f...
# 1688                    💎 Infrastructure: Automated Build
# 1689              💎 Infrastructure: Provisioning Profiles
# 1940                                     💎 Search Results
# 700                                                     😁
# 701                                                     😘
#
#                                                SourceLink  \
# 7081    https://msasg.visualstudio.com/DefaultCollecti...
# 278811  https://msasg.visualstudio.com/DefaultCollecti...
# 278810  https://msasg.visualstudio.com/DefaultCollecti...
# 278809  https://msasg.visualstudio.com/DefaultCollecti...
# 278808  https://msasg.visualstudio.com/DefaultCollecti...
# 278807  https://msasg.visualstudio.com/DefaultCollecti...
# 278806  https://msasg.visualstudio.com/DefaultCollecti...
# 278805  https://msasg.visualstudio.com/DefaultCollecti...
# 278804  https://msasg.visualstudio.com/DefaultCollecti...
# 278803  https://msasg.visualstudio.com/DefaultCollecti...
# 278802  https://msasg.visualstudio.com/DefaultCollecti...
# 278801  https://msasg.visualstudio.com/DefaultCollecti...
# 278800  https://msasg.visualstudio.com/DefaultCollecti...
# 824015  https://msasg.visualstudio.com/DefaultCollecti...
# 824014  https://msasg.visualstudio.com/DefaultCollecti...
# 278812  https://msasg.visualstudio.com/DefaultCollecti...
# 824013  https://msasg.visualstudio.com/DefaultCollecti...
# 254614  https://msasg.visualstudio.com/DefaultCollecti...
# 278799  https://msasg.visualstudio.com/DefaultCollecti...
# 278798  https://msasg.visualstudio.com/DefaultCollecti...
# 742967  https://msasg.visualstudio.com/DefaultCollecti...
# 742688  https://msasg.visualstudio.com/DefaultCollecti...
# 695353  https://msasg.visualstudio.com/DefaultCollecti...
# 278797  https://msasg.visualstudio.com/DefaultCollecti...
# 255842  https://msasg.visualstudio.com/DefaultCollecti...
# 278796  https://msasg.visualstudio.com/DefaultCollecti...
# 823363  https://msasg.visualstudio.com/DefaultCollecti...
# 278795  https://msasg.visualstudio.com/DefaultCollecti...
# 466438  https://msasg.visualstudio.com/DefaultCollecti...
# 466437  https://msasg.visualstudio.com/DefaultCollecti...
# ...                                                   ...
# 1736    https://msasg.visualstudio.com/DefaultCollecti...
# 1789    https://msasg.visualstudio.com/DefaultCollecti...
# 1826    https://msasg.visualstudio.com/DefaultCollecti...
# 1827    https://msasg.visualstudio.com/DefaultCollecti...
# 1839    https://msasg.visualstudio.com/DefaultCollecti...
# 1840    https://msasg.visualstudio.com/DefaultCollecti...
# 1834    https://msasg.visualstudio.com/DefaultCollecti...
# 1975    https://msasg.visualstudio.com/DefaultCollecti...
# 1976    https://msasg.visualstudio.com/DefaultCollecti...
# 1744    https://msasg.visualstudio.com/DefaultCollecti...
# 698     https://msasg.visualstudio.com/DefaultCollecti...
# 699     https://msasg.visualstudio.com/DefaultCollecti...
# 1477    https://msasg.visualstudio.com/DefaultCollecti...
# 1544    https://msasg.visualstudio.com/DefaultCollecti...
# 875     https://msasg.visualstudio.com/DefaultCollecti...
# 876     https://msasg.visualstudio.com/DefaultCollecti...
# 877     https://msasg.visualstudio.com/DefaultCollecti...
# 878     https://msasg.visualstudio.com/DefaultCollecti...
# 879     https://msasg.visualstudio.com/DefaultCollecti...
# 880     https://msasg.visualstudio.com/DefaultCollecti...
# 1569    https://msasg.visualstudio.com/DefaultCollecti...
# 1604    https://msasg.visualstudio.com/DefaultCollecti...
# 1629    https://msasg.visualstudio.com/DefaultCollecti...
# 1663    https://msasg.visualstudio.com/DefaultCollecti...
# 1664    https://msasg.visualstudio.com/DefaultCollecti...
# 1688    https://msasg.visualstudio.com/DefaultCollecti...
# 1689    https://msasg.visualstudio.com/DefaultCollecti...
# 1940    https://msasg.visualstudio.com/DefaultCollecti...
# 700     https://msasg.visualstudio.com/DefaultCollecti...
# 701     https://msasg.visualstudio.com/DefaultCollecti...
#
#        RequirementCollectionDID  \
# 7081                       None
# 278811                     None
# 278810                     None
# 278809                     None
# 278808                     None
# 278807                     None
# 278806                     None
# 278805                     None
# 278804                     None
# 278803                     None
# 278802                     None
# 278801                     None
# 278800                     None
# 824015                     None
# 824014                     None
# 278812                     None
# 824013                     None
# 254614                     None
# 278799                     None
# 278798                     None
# 742967                     None
# 742688                     None
# 695353                     None
# 278797                     None
# 255842                     None
# 278796                     None
# 823363                     None
# 278795                     None
# 466438                     None
# 466437                     None
# ...                         ...
# 1736                       None
# 1789                       None
# 1826                       None
# 1827                       None
# 1839                       None
# 1840                       None
# 1834                       None
# 1975                       None
# 1976                       None
# 1744                       None
# 698                        None
# 699                        None
# 1477                       None
# 1544                       None
# 875                        None
# 876                        None
# 877                        None
# 878                        None
# 879                        None
# 880                        None
# 1569                       None
# 1604                       None
# 1629                       None
# 1663                       None
# 1664                       None
# 1688                       None
# 1689                       None
# 1940                       None
# 700                        None
# 701                        None
#
#                                                   No Urls  \
# 7081                                              //Build
# 278811                                                 {}
# 278810                                                 {}
# 278809                                                 {}
# 278808                                                 {}
# 278807                                                 {}
# 278806                                                 {}
# 278805                                                 {}
# 278804                                                 {}
# 278803                                                 {}
# 278802                                                 {}
# 278801                                                 {}
# 278800                                                 {}
# 824015                                         Open/Close
# 824014                                         Open/Close
# 278812                                                 {}
# 824013                                         Open/Close
# 254614  [TestFailure][SI][BVT][11/28/2017]HotelCenter_...
# 278799                                                 {}
# 278798                                                 {}
# 742967                                       Logs/Metrics
# 742688                                Logging/Diagnostics
# 695353                                        List/Search
# 278797                                                 {}
# 255842  [ThresholdPC][Proactive][个人信息][最喜爱的地方]:编辑收藏夹地址...
# 278796                                                 {}
# 823363                                          OOBE/FTUE
# 278795                                                 {}
# 466438                                         CR/testing
# 466437                                         CR/Testing
# ...                                                   ...
# 1736        🍩 Landscape (and arbitrary size) mode support
# 1789    🍩 Move photo client-side filters (colors, lamd...
# 1826                              🍩 Open items (S4L Team)
# 1827                        🍩 Open items (Sprinkles Team)
# 1839    🍩 PM: Branding -- something Jamil should follo...
# 1840    🍩 PM: CELA pass – combined across bing and sky...
# 1834    🍩 Performance, multiple-calls, thread-safety, ...
# 1975               🍩 Sticker Service: Photo frame support
# 1976                   🍩 Sticker Service: Weather Sticker
# 1744    🍩 Live-site/production readiness ⛑(tests, xpin...
# 698                                                     👌
# 699                                                     👍
# 1477                                  💎 Camera As Input 📸
# 1544                                        💎 Detail Page
# 875                     💎 [Diamond MVP]: Explore/Trending
# 876      💎 [Diamond MVP]: Initial User Interest Settings
# 877     💎 [Diamond MVP]: My Account (Saves, Profile, S...
# 878     💎 [Diamond MVP]: Personalized Feed (Daily Dige...
# 879     💎 [Diamond MVP]: Process Related (Daily Build,...
# 880     💎 [Diamond MVP]: User Sign In (Facebook, Micro...
# 1569                      💎 Enable Hockey App (with Paul)
# 1604                                     💎 Favorites page
# 1629                                            💎 General
# 1663                      💎 Image App: Navigation/Tabbing
# 1664    💎 Image App: Sign In (Pending shared control f...
# 1688                    💎 Infrastructure: Automated Build
# 1689              💎 Infrastructure: Provisioning Profiles
# 1940                                     💎 Search Results
# 700                                                     😁
# 701                                                     😘
#
#                                                  No Paths  \
# 7081                                              //Build
# 278811                                                 {}
# 278810                                                 {}
# 278809                                                 {}
# 278808                                                 {}
# 278807                                                 {}
# 278806                                                 {}
# 278805                                                 {}
# 278804                                                 {}
# 278803                                                 {}
# 278802                                                 {}
# 278801                                                 {}
# 278800                                                 {}
# 824015                                         Open/Close
# 824014                                         Open/Close
# 278812                                                 {}
# 824013                                         Open/Close
# 254614  [TestFailure][SI][BVT][11/28/2017]HotelCenter_...
# 278799                                                 {}
# 278798                                                 {}
# 742967                                       Logs/Metrics
# 742688                                Logging/Diagnostics
# 695353                                        List/Search
# 278797                                                 {}
# 255842  [ThresholdPC][Proactive][个人信息][最喜爱的地方]:编辑收藏夹地址...
# 278796                                                 {}
# 823363                                          OOBE/FTUE
# 278795                                                 {}
# 466438                                         CR/testing
# 466437                                         CR/Testing
# ...                                                   ...
# 1736        🍩 Landscape (and arbitrary size) mode support
# 1789    🍩 Move photo client-side filters (colors, lamd...
# 1826                              🍩 Open items (S4L Team)
# 1827                        🍩 Open items (Sprinkles Team)
# 1839    🍩 PM: Branding -- something Jamil should follo...
# 1840    🍩 PM: CELA pass – combined across bing and sky...
# 1834    🍩 Performance, multiple-calls, thread-safety, ...
# 1975               🍩 Sticker Service: Photo frame support
# 1976                   🍩 Sticker Service: Weather Sticker
# 1744    🍩 Live-site/production readiness ⛑(tests, xpin...
# 698                                                     👌
# 699                                                     👍
# 1477                                  💎 Camera As Input 📸
# 1544                                        💎 Detail Page
# 875                     💎 [Diamond MVP]: Explore/Trending
# 876      💎 [Diamond MVP]: Initial User Interest Settings
# 877     💎 [Diamond MVP]: My Account (Saves, Profile, S...
# 878     💎 [Diamond MVP]: Personalized Feed (Daily Dige...
# 879     💎 [Diamond MVP]: Process Related (Daily Build,...
# 880     💎 [Diamond MVP]: User Sign In (Facebook, Micro...
# 1569                      💎 Enable Hockey App (with Paul)
# 1604                                     💎 Favorites page
# 1629                                            💎 General
# 1663                      💎 Image App: Navigation/Tabbing
# 1664    💎 Image App: Sign In (Pending shared control f...
# 1688                    💎 Infrastructure: Automated Build
# 1689              💎 Infrastructure: Provisioning Profiles
# 1940                                     💎 Search Results
# 700                                                     😁
# 701                                                     😘
#
#                                        No Links and Paths  \
# 7081
# 278811                                                 {}
# 278810                                                 {}
# 278809                                                 {}
# 278808                                                 {}
# 278807                                                 {}
# 278806                                                 {}
# 278805                                                 {}
# 278804                                                 {}
# 278803                                                 {}
# 278802                                                 {}
# 278801                                                 {}
# 278800                                                 {}
# 824015
# 824014
# 278812                                                 {}
# 824013
# 254614
# 278799                                                 {}
# 278798                                                 {}
# 742967
# 742688
# 695353
# 278797                                                 {}
# 255842
# 278796                                                 {}
# 823363
# 278795                                                 {}
# 466438
# 466437
# ...                                                   ...
# 1736        🍩 Landscape (and arbitrary size) mode support
# 1789    🍩 Move photo client-side filters (colors, lamd...
# 1826                              🍩 Open items (S4L Team)
# 1827                        🍩 Open items (Sprinkles Team)
# 1839    🍩 PM: Branding -- something Jamil should follo...
# 1840    🍩 PM: CELA pass – combined across bing and sky...
# 1834    🍩 Performance, multiple-calls, thread-safety, ...
# 1975               🍩 Sticker Service: Photo frame support
# 1976                   🍩 Sticker Service: Weather Sticker
# 1744                       🍩 readiness ⛑(tests, DRI, etc)
# 698                                                     👌
# 699                                                     👍
# 1477                                  💎 Camera As Input 📸
# 1544                                        💎 Detail Page
# 875                                      💎 [Diamond MVP]:
# 876       💎 [Diamond MVP]: Initial User Interest Settings
# 877     💎 [Diamond MVP]: My Account (Saves, Profile, S...
# 878     💎 [Diamond MVP]: Personalized Feed (Daily Dige...
# 879     💎 [Diamond MVP]: Process Related (Daily Build,...
# 880     💎 [Diamond MVP]: User Sign In (Facebook, Micro...
# 1569                      💎 Enable Hockey App (with Paul)
# 1604                                     💎 Favorites page
# 1629                                            💎 General
# 1663                                         💎 Image App:
# 1664    💎 Image App: Sign In (Pending shared control f...
# 1688                    💎 Infrastructure: Automated Build
# 1689              💎 Infrastructure: Provisioning Profiles
# 1940                                     💎 Search Results
# 700                                                     😁
# 701                                                     😘
#
#                                               Split Upper  \
# 7081
# 278811                                                 {}
# 278810                                                 {}
# 278809                                                 {}
# 278808                                                 {}
# 278807                                                 {}
# 278806                                                 {}
# 278805                                                 {}
# 278804                                                 {}
# 278803                                                 {}
# 278802                                                 {}
# 278801                                                 {}
# 278800                                                 {}
# 824015
# 824014
# 278812                                                 {}
# 824013
# 254614
# 278799                                                 {}
# 278798                                                 {}
# 742967
# 742688
# 695353
# 278797                                                 {}
# 255842
# 278796                                                 {}
# 823363
# 278795                                                 {}
# 466438
# 466437
# ...                                                   ...
# 1736       🍩  Landscape (and arbitrary size) mode support
# 1789    🍩  Move photo client-side filters (colors, lam...
# 1826                            🍩  Open items (S4L  Team)
# 1827                     🍩  Open items ( Sprinkles  Team)
# 1839    🍩 PM:  Branding -- something  Jamil should fol...
# 1840    🍩 PM: CELA pass – combined across bing and sky...
# 1834    🍩  Performance, multiple-calls, thread-safety,...
# 1975            🍩  Sticker  Service:  Photo frame support
# 1976               🍩  Sticker  Service:  Weather  Sticker
# 1744                       🍩 readiness ⛑(tests, DRI, etc)
# 698                                                     👌
# 699                                                     👍
# 1477                               💎  Camera  As  Input 📸
# 1544                                      💎  Detail  Page
# 875                                     💎 [ Diamond MVP]:
# 876     💎 [ Diamond MVP]:  Initial  User  Interest  Se...
# 877     💎 [ Diamond MVP]:  My  Account ( Saves,  Profi...
# 878     💎 [ Diamond MVP]:  Personalized  Feed ( Daily ...
# 879     💎 [ Diamond MVP]:  Process  Related ( Daily  B...
# 880     💎 [ Diamond MVP]:  User  Sign  In ( Facebook, ...
# 1569                  💎  Enable  Hockey  App (with  Paul)
# 1604                                    💎  Favorites page
# 1629                                           💎  General
# 1663                                       💎  Image  App:
# 1664    💎  Image  App:  Sign  In ( Pending shared cont...
# 1688                 💎  Infrastructure:  Automated  Build
# 1689           💎  Infrastructure:  Provisioning  Profiles
# 1940                                   💎  Search  Results
# 700                                                     😁
# 701                                                     😘
#
#                                            No Punctuation  \
# 7081
# 278811
# 278810
# 278809
# 278808
# 278807
# 278806
# 278805
# 278804
# 278803
# 278802
# 278801
# 278800
# 824015
# 824014
# 278812
# 824013
# 254614
# 278799
# 278798
# 742967
# 742688
# 695353
# 278797
# 255842
# 278796
# 823363
# 278795
# 466438
# 466437
# ...                                                   ...
# 1736          🍩 Landscape and arbitrary size mode support
# 1789    🍩 Move photo client side filters colors lamda ...
# 1826                                🍩 Open items S4L Team
# 1827                          🍩 Open items Sprinkles Team
# 1839    🍩 PM Branding something Jamil should follow up...
# 1840    🍩 PM CELA pass – combined across bing and skyp...
# 1834    🍩 Performance multiple calls thread safety sca...
# 1975                🍩 Sticker Service Photo frame support
# 1976                    🍩 Sticker Service Weather Sticker
# 1744                          🍩 readiness ⛑ tests DRI etc
# 698                                                     👌
# 699                                                     👍
# 1477                                  💎 Camera As Input 📸
# 1544                                        💎 Detail Page
# 875                                         💎 Diamond MVP
# 876          💎 Diamond MVP Initial User Interest Settings
# 877     💎 Diamond MVP My Account Saves Profile Setting...
# 878     💎 Diamond MVP Personalized Feed Daily Digest T...
# 879     💎 Diamond MVP Process Related Daily Build Hock...
# 880         💎 Diamond MVP User Sign In Facebook Microsoft
# 1569                        💎 Enable Hockey App with Paul
# 1604                                     💎 Favorites page
# 1629                                            💎 General
# 1663                                          💎 Image App
# 1664    💎 Image App Sign In Pending shared control fro...
# 1688                     💎 Infrastructure Automated Build
# 1689               💎 Infrastructure Provisioning Profiles
# 1940                                     💎 Search Results
# 700                                                     😁
# 701                                                     😘
#
#                                               Clean Title  Predictions  \
# 7081                                                             False
# 278811                                                           False
# 278810                                                           False
# 278809                                                           False
# 278808                                                           False
# 278807                                                           False
# 278806                                                           False
# 278805                                                           False
# 278804                                                           False
# 278803                                                           False
# 278802                                                           False
# 278801                                                           False
# 278800                                                           False
# 824015                                                           False
# 824014                                                           False
# 278812                                                           False
# 824013                                                           False
# 254614                                                           False
# 278799                                                           False
# 278798                                                           False
# 742967                                                           False
# 742688                                                           False
# 695353                                                           False
# 278797                                                           False
# 255842                                                           False
# 278796                                                           False
# 823363                                                           False
# 278795                                                           False
# 466438                                                           False
# 466437                                                           False
# ...                                                   ...          ...
# 1736          🍩 Landscape and arbitrary size mode support        False
# 1789    🍩 Move photo client side filters colors lamda ...        False
# 1826                                🍩 Open items S4L Team        False
# 1827                          🍩 Open items Sprinkles Team        False
# 1839    🍩 PM Branding something Jamil should follow up...        False
# 1840    🍩 PM CELA pass – combined across bing and skyp...        False
# 1834    🍩 Performance multiple calls thread safety sca...        False
# 1975                🍩 Sticker Service Photo frame support        False
# 1976                    🍩 Sticker Service Weather Sticker        False
# 1744                          🍩 readiness ⛑ tests DRI etc        False
# 698                                                     👌        False
# 699                                                     👍        False
# 1477                                  💎 Camera As Input 📸        False
# 1544                                        💎 Detail Page        False
# 875                                         💎 Diamond MVP        False
# 876          💎 Diamond MVP Initial User Interest Settings        False
# 877     💎 Diamond MVP My Account Saves Profile Setting...        False
# 878     💎 Diamond MVP Personalized Feed Daily Digest T...        False
# 879     💎 Diamond MVP Process Related Daily Build Hock...        False
# 880         💎 Diamond MVP User Sign In Facebook Microsoft        False
# 1569                        💎 Enable Hockey App with Paul        False
# 1604                                     💎 Favorites page        False
# 1629                                            💎 General        False
# 1663                                          💎 Image App        False
# 1664    💎 Image App Sign In Pending shared control fro...        False
# 1688                     💎 Infrastructure Automated Build        False
# 1689               💎 Infrastructure Provisioning Profiles        False
# 1940                                     💎 Search Results        False
# 700                                                     😁        False
# 701                                                     😘        False
#
#         Pred_Proba0  Pred_Proba1  Predictions_fewTypes  Pred_Proba0_fewTypes  \
# 7081       0.996670     0.003330                 False              0.998447
# 278811     0.996670     0.003330                 False              0.998447
# 278810     0.996670     0.003330                 False              0.998447
# 278809     0.996670     0.003330                 False              0.998447
# 278808     0.996670     0.003330                 False              0.998447
# 278807     0.996670     0.003330                 False              0.998447
# 278806     0.996670     0.003330                 False              0.998447
# 278805     0.996670     0.003330                 False              0.998447
# 278804     0.996670     0.003330                 False              0.998447
# 278803     0.996670     0.003330                 False              0.998447
# 278802     0.996670     0.003330                 False              0.998447
# 278801     0.996670     0.003330                 False              0.998447
# 278800     0.996670     0.003330                 False              0.998447
# 824015     0.996670     0.003330                 False              0.998447
# 824014     0.996670     0.003330                 False              0.998447
# 278812     0.996670     0.003330                 False              0.998447
# 824013     0.996670     0.003330                 False              0.998447
# 254614     0.996670     0.003330                 False              0.998447
# 278799     0.996670     0.003330                 False              0.998447
# 278798     0.996670     0.003330                 False              0.998447
# 742967     0.996670     0.003330                 False              0.998447
# 742688     0.996670     0.003330                 False              0.998447
# 695353     0.996670     0.003330                 False              0.998447
# 278797     0.996670     0.003330                 False              0.998447
# 255842     0.996670     0.003330                 False              0.998447
# 278796     0.996670     0.003330                 False              0.998447
# 823363     0.996670     0.003330                 False              0.998447
# 278795     0.996670     0.003330                 False              0.998447
# 466438     0.996670     0.003330                 False              0.998447
# 466437     0.996670     0.003330                 False              0.998447
# ...             ...          ...                   ...                   ...
# 1736       0.994107     0.005893                 False              0.993683
# 1789       0.992529     0.007471                 False              0.997516
# 1826       0.999150     0.000850                 False              0.998066
# 1827       0.997149     0.002851                 False              0.994061
# 1839       0.999695     0.000305                 False              0.999845
# 1840       0.998140     0.001860                 False              0.999849
# 1834       0.998680     0.001320                 False              0.999313
# 1975       0.984092     0.015908                 False              0.997902
# 1976       0.998630     0.001370                 False              0.998329
# 1744       0.996665     0.003335                 False              0.997703
# 698        0.996670     0.003330                 False              0.998447
# 699        0.996670     0.003330                 False              0.998447
# 1477       0.995411     0.004589                 False              0.997780
# 1544       0.992789     0.007211                 False              0.995787
# 875        0.997195     0.002805                 False              0.998447
# 876        0.998620     0.001380                 False              0.997947
# 877        0.997690     0.002310                 False              0.999168
# 878        0.998520     0.001480                 False              0.999131
# 879        0.998790     0.001210                 False              0.999503
# 880        0.995270     0.004730                 False              0.997200
# 1569       0.999126     0.000874                 False              0.999715
# 1604       0.998759     0.001241                 False              0.998080
# 1629       0.994841     0.005159                 False              0.995648
# 1663       0.996472     0.003528                 False              0.999346
# 1664       0.991266     0.008734                 False              0.998033
# 1688       0.988871     0.011129                 False              0.980848
# 1689       0.997137     0.002863                 False              0.997616
# 1940       0.998522     0.001478                 False              0.999308
# 700        0.996670     0.003330                 False              0.998447
# 701        0.996670     0.003330                 False              0.998447
#
#         Pred_Proba1_fewTypes
# 7081                0.001553
# 278811              0.001553
# 278810              0.001553
# 278809              0.001553
# 278808              0.001553
# 278807              0.001553
# 278806              0.001553
# 278805              0.001553
# 278804              0.001553
# 278803              0.001553
# 278802              0.001553
# 278801              0.001553
# 278800              0.001553
# 824015              0.001553
# 824014              0.001553
# 278812              0.001553
# 824013              0.001553
# 254614              0.001553
# 278799              0.001553
# 278798              0.001553
# 742967              0.001553
# 742688              0.001553
# 695353              0.001553
# 278797              0.001553
# 255842              0.001553
# 278796              0.001553
# 823363              0.001553
# 278795              0.001553
# 466438              0.001553
# 466437              0.001553
# ...                      ...
# 1736                0.006317
# 1789                0.002484
# 1826                0.001934
# 1827                0.005939
# 1839                0.000155
# 1840                0.000151
# 1834                0.000687
# 1975                0.002098
# 1976                0.001671
# 1744                0.002297
# 698                 0.001553
# 699                 0.001553
# 1477                0.002220
# 1544                0.004213
# 875                 0.001553
# 876                 0.002053
# 877                 0.000832
# 878                 0.000869
# 879                 0.000497
# 880                 0.002800
# 1569                0.000285
# 1604                0.001920
# 1629                0.004352
# 1663                0.000654
# 1664                0.001967
# 1688                0.019152
# 1689                0.002384
# 1940                0.000692
# 700                 0.001553
# 701                 0.001553
#
# [1071262 rows x 15 columns]

# %% [markdown]
# Get the msasf titles with the same type condition as that in the query that we had used in building the first moded ie <br>  `Type IN ('bug', 'Compliance Issue', 'Defect', 'Issue', 'RDBug')`

# %%
conn = pyodbc.connect(r'Driver={SQL Server};Server=dotdatarpt;Database=TwCDataWarehouse;Trusted_Connection=yes;OPTION=3;applicationintent=readonly;')

msasg_data1 = pd.read_sql('''SELECT DISTINCT Title, SourceLink, RequirementCollectionDID 
                          FROM workitemextensions WITH (NOLOCK)
                          WHERE IsActive = 1 AND LatestFlag = 1 
                          AND Type IN ('bug', 'Compliance Issue', 'Defect', 'Issue', 'RDBug')
                          AND SourceLink like '%msasg.visualstudio.com%' ''', conn)
conn.close()
msasg_data1.info()
# and Type LIKE '%bug%'
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457700 entries, 0 to 457699
# Data columns (total 3 columns):
# Title                       457700 non-null object
# SourceLink                  457700 non-null object
# RequirementCollectionDID    29295 non-null object
# dtypes: object(3)
# memory usage: 10.5+ MB

# %%
msasg_data1['Title'] = msasg_data1['Title'].apply(str)

# %%
msasg_data1['Title'] = msasg_data1['Title'].apply(deal_with_policheck)

# %%
msasg_data1['No Urls'] = msasg_data1['Title'].apply(clean_review_html)

# %%
msasg_data1['No Paths'] = msasg_data1['No Urls'].apply(clean_review_path)

# %%
msasg_data1['No Links and Paths'] = msasg_data1['No Paths'].apply(remove_paths_urls)

# %%
msasg_data1['Split Upper'] = msasg_data1['No Links and Paths'].apply(split_on_uppercase)

# %%
msasg_data1['No Punctuation'] = msasg_data1['Split Upper'].apply(remove_punctuation)

# %%
msasg_data1['Clean Title'] = msasg_data1['No Punctuation'].apply(remove_integers)

# %% [markdown]
# Transform the 'No Punctuation' column and get predictions on it.

# %%
X2 = tv.transform(msasg_data1['No Punctuation'])

# %% [markdown]
# Get the predictions on the transformed titles.

# %%
msasg_data1['Predictions_fewTypes'], msasg_data1['Pred_Proba0_fewTypes'], msasg_data1['Pred_Proba1_fewTypes'] = model.predict(X2), model.predict_proba(X2)[:,0], model.predict_proba(X2)[:,1]

# %%
msasg_data.columns
# Out:
# Index(['Title', 'SourceLink', 'RequirementCollectionDID', 'No Urls',
#        'No Paths', 'No Links and Paths', 'Split Upper', 'No Punctuation',
#        'Clean Title', 'Predictions_fewTypes', 'Pred_Proba0_fewTypes',
#        'Pred_Proba1_fewTypes'],
#       dtype='object')

# %%
['Title', 'SourceLink', 'RequirementCollectionDID', 'No Urls',
       'No Paths', 'No Links and Paths', 'Split Upper', 'No Punctuation',
       'Clean Title', 'Predictions_fewTypes', 'Pred_Proba0_fewTypes',
       'Pred_Proba1_fewTypes']

# %%
msasg_data['Predictions_fewTypes'].value_counts()
# Out:
# False    428803
# True      28897
# Name: Predictions_fewTypes, dtype: int64

# %%
msasg_data[['Title', 'SourceLink', 'RequirementCollectionDID','Predictions_fewTypes', 'Pred_Proba0_fewTypes', 'Pred_Proba1_fewTypes']].to_csv('Predictions on msasg titles.csv.csv', index = False)
